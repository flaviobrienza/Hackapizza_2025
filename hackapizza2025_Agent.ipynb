# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_experimental.agents import create_pandas_dataframe_agent
from langchain_experimental.tools import PythonAstREPLTool
from langchain_community.document_loaders import PyPDFLoader

import os
from key import openai_api_key

os.environ['OPENAI_API_KEY'] = openai_api_key


import warnings
warnings.simplefilter(action='ignore')

# %% [markdown]
# # Importing Dataset

# %%
tecniche = pd.read_csv('tecniche_finale.csv')
ordini_galattici = pd.read_csv('Hackapizza Dataset\Misc\ordini.csv')
licenze = pd.read_csv('Hackapizza Dataset\Misc\licenze.csv')
menus = pd.read_csv('Menus to Use\dataset_finale_menu_licenze_tecniche.csv')

# %% [markdown]
# # Agent Creation

# %% [markdown]
# ## Formattatore

# %%
# Model
formattatore_llm = ChatOpenAI(temperature=.3, model='gpt-4o')

# Prompt
formattatore_prompt = PromptTemplate(
    template='''
    Ruolo:
    Sei il Formattatore, il tuo compito è ricevere una domanda dall'utente e fornire istruzioni dettagliate all’Assistente su come effettuare query sui dataset disponibili.
    
    Dataset a disposizione dell'Assistente:
    
    menus: Contiene i piatti disponibili con dettagli su ristorante, chef, pianeta, tecniche di preparazione, licenze necessarie, ingredienti e ID del piatto.
    tecniche: Contiene informazioni sulle tecniche di cucina del famoso chef Sirius Cosmo, è uno chef non una tecnica o un piatto, suddivise in tre categorie: Preparazione, Cottura e Avanzate. Ogni tecnica ha un nome, una breve descrizione e il grado richiesto per eseguirla.
    ordini_galattici: Contiene restrizioni alimentari per tre ordini (Ordine della Galassia di Andromeda, Ordine dei Naturalisti, Ordine degli Armonisti).
    abilita: Contiene informazioni sulle abilità richieste per cucinare determinati piatti, con nome, sigla e livelli disponibili.
    
    Regole fondamentali:
    
    Esiste sempre almeno un piatto che soddisfa la richiesta dell'utente.
    La tua risposta deve essere strutturata in step chiari e sequenziali, indicando quali operazioni l'Assistente deve eseguire sui dataset.
    Se la domanda fa riferimento a tecniche, licenze o restrizioni alimentari, devi identificare i dataset rilevanti e fornire i criteri di filtraggio adeguati.
    L’output finale dell’Assistente sarà una lista ordinata di ID dei piatti che soddisfano la richiesta.
    Esempi di istruzioni:
    
    Domanda: "Quali piatti utilizzano almeno una tecnica di taglio e una di surgelamento?"
    Istruzioni per l’Assistente:
    
    Filtra il dataset tecniche per ottenere l'elenco delle tecniche di Taglio e Surgelamento.
    Estrai i nomi di queste tecniche.
    Filtra il dataset menus per individuare i piatti che utilizzano almeno una tecnica di ciascuna categoria.
    Restituisci gli ID dei piatti ordinati in ordine crescente.
    Domanda: "Mostrami i piatti che possono essere preparati solo da chi possiede una licenza di livello III in Psionica."
    Istruzioni per l’Assistente:
    
    Filtra il dataset abilita per individuare la licenza Psionica III.
    Filtra il dataset menus per trovare i piatti che richiedono questa licenza.
    Restituisci gli ID dei piatti ordinati in ordine crescente.
    Domanda: "Trova un piatto compatibile con l’Ordine della Galassia di Andromeda che utilizzi almeno una tecnica di fermentazione."
    Istruzioni per l’Assistente:
    
    Consulta il dataset ordini_galattici per identificare gli ingredienti vietati per l’Ordine della Galassia di Andromeda.
    Filtra il dataset menus per escludere i piatti contenenti questi ingredienti.
    Filtra il dataset tecniche per ottenere l’elenco delle tecniche di Fermentazione.
    Filtra nuovamente menus per individuare i piatti che utilizzano almeno una di queste tecniche.
    Restituisci gli ID dei piatti ordinati in ordine crescente.
    La tua risposta deve essere precisa, completa e strutturata per facilitare l'elaborazione dell’Assistente.
    L'utente non chiede di individuare un piatto dal suo nome, bensì dagli ingredienti o altre caratteristiche.


    Devi essere specifico capendo che la maggior parte delle colonne sono stringhe, dunque filtrare è complesso per l'assistente. 

    Domanda utente: {domanda_originale}
    ''',
    input_variables = ['domanda_originale']
)

# Formattatore chain
formattatore = formattatore_prompt | formattatore_llm | StrOutputParser()

# %% [markdown]
# ## Assistente

# %%
# Funzione per impedire il NameError in fase di tool invocation

PythonAstREPLTool_init = PythonAstREPLTool.__init__

def PythonAstREPLTool_init_wrapper(self, *args, **kwargs):
    PythonAstREPLTool_init(self, *args, **kwargs)
    self.globals = self.locals

PythonAstREPLTool.__init__ = PythonAstREPLTool_init_wrapper

# %%
# Model
assistente_llm = ChatOpenAI(temperature=.3, model='gpt-4o')

# Assistente

assistente_agent = create_pandas_dataframe_agent(
    assistente_llm,
    [tecniche, ordini_galattici, menus, tecniche],
    agent_type='openai-functions',
    extra_tools=[PythonAstREPLTool()],
    verbose=False,
    allow_dangerous_code=True,
    prefix='''
    Sei l’Assistente, il tuo compito è eseguire query su dataset pandas seguendo scrupolosamente le istruzioni fornite dal Formattatore. Alla fine, devi restituire gli ID dei piatti ordinati in ordine crescente.

    Dataset a tua disposizione:
    
    menus: Ogni riga rappresenta un piatto e include informazioni su ristorante, chef, pianeta, tecniche di preparazione, licenze richieste, ingredienti e ID del piatto.
    Path per accedere a menus: "galactic_menus.csv"
    
    tecniche: Contiene tecniche di cucina suddivise in tre categorie (Preparazione, Cottura, Avanzate), con nomi, descrizioni e grado richiesto per eseguirle.
    Path per accedere a tecniche: "tecniche_finale.csv"
    
    ordini_galattici: Contiene restrizioni alimentari per tre ordini (Ordine della Galassia di Andromeda, Ordine dei Naturalisti, Ordine degli Armonisti).
    Path per accedere a ordini_galattici: "Hackapizza Dataset\Misc\ordini.csv"

    abilita: Contiene informazioni sulle abilità necessarie per preparare determinati piatti, incluse sigle e livelli disponibili.
    Path per accedere a abilita: "Hackapizza Dataset\Misc\licenze.csv"
    
    Come operare:
    
    Leggi attentamente le istruzioni fornite dal Formattatore.
    Identifica i dataset da interrogare e i criteri di filtraggio richiesti.
    Applica le operazioni di filtraggio e selezione per ottenere il risultato corretto.
    Restituisci una lista di ID dei piatti in ordine crescente.
    Esempi di richieste che potresti ricevere:
    
    "Trova i piatti che utilizzano almeno una tecnica di Taglio e una di Surgelamento."
    
    Devi estrarre l'elenco delle tecniche di queste due categorie e filtrare i piatti che ne usano almeno una per ciascuna.
    "Individua i piatti compatibili con l'Ordine della Galassia di Andromeda, che non contengono ingredienti vietati e usano almeno una tecnica di Fermentazione."
    
    Devi escludere i piatti con ingredienti proibiti e selezionare quelli che usano una tecnica di fermentazione.
    "Trova i piatti che richiedono almeno una licenza di livello II o superiore."
    
    Devi individuare le licenze di livello II o superiore e filtrare i piatti che le richiedono.
    Regole importanti:
    
    Ricorda che Sirius Cosmo è solo uno chef. Non appare nel dataset.
    Segui esattamente le istruzioni fornite dal Formattatore.
    Usa solo i dataset disponibili e le operazioni indicate.
    Restituisci sempre una lista di ID in ordine crescente.
    Seleziona solo le colonne necessarie per ottimizzare le query.
    Il tuo obiettivo è ottenere il risultato corretto nel modo più efficiente possibile. 
    Devi sempre restituire almeno un id. Esiste sempre almeno un piatto che soddisfa la richiesta. 
    Se non trovi un piatto cerca meglio, magari correggendo possibili errori di battitura oppure ampliando la ricerca.
    Non puoi rispondere che un piatto non esiste. Esiste per forza almeno un piatto.

    Gestione degli errori di battitura negli ingredienti
    Gli ingredienti presenti nel dataset menus potrebbero contenere errori di battitura o leggere variazioni nel nome. Se un ingrediente specificato nella richiesta dell'utente non corrisponde esattamente a nessuno di quelli nel dataset, devi:

    Cercare la corrispondenza più simile nel dataset usando una misura di similarità testuale (es. confronto del numero di caratteri uguali o la distanza di Levenshtein).
    Scegliere l'ingrediente con il nome più vicino a quello richiesto, purché la differenza sia minima e non alteri significativamente il significato.
    Se ci sono più alternative valide, preferire quella con la somiglianza più alta.
    Esempio:

    L'utente chiede un piatto senza "Polvere di Crononitte", ma nel dataset trovi solo "Polvere di Crononite". In questo caso, devi trattarli come lo stesso ingrediente ed escludere i piatti che lo contengono.
    Se l'utente cerca un piatto con "Fungo Stellare" ma trovi solo "Funghi Stellari", considerali equivalenti.
    L'obiettivo è evitare di scartare piatti corretti solo a causa di piccoli errori di scrittura.
    
    Non usare altre librerie oltre pandas.
    
    Restituisci solo l'id o gli id che trovi, senza aggiungere altro. Ad esempio:
     "1"
     "3, 19"
    
    ''',
    max_iterations=5
    )

# Assistente chain
assistente = {'input':RunnablePassthrough()} | assistente_agent | (lambda x: x['output'])

# %% [markdown]
# ## Flusso

# %%
questions = (pd.read_csv('Hackapizza Dataset\domande.csv')
             .domanda
             .values
             .tolist())

# %%
final_answers = {}

# %%
# Defining the question
question = questions[0] # inserire domanda

# Formattatore
risposta_formattatore = formattatore.invoke(
     {
          'domanda_originale':question
     }
)

# Assistente
risposta_assistente = assistente.invoke(risposta_formattatore)

# Append to list
final_answers['1'] = [risposta_assistente]
final_answers[list(final_answers.keys())[-1]]

# %% [markdown]
# # Submission

# %%
final_answers

# %% [markdown]
# # Terza Run
#
# Questa run sarà volta al miglioramento del risultato precedente andando ad usare il dataset exploded.

# %% [markdown]
# ## Step 1 - Uniformare la Colonna Livello

# %% [markdown]
# Conversione della colonna livello.
# Per ogni menù viene uniformata la colonna livello, mettendo solo numeri arabi.

# %%
# Funzione per ottnere il documento
def full_doc(doc):
    loaded_doc = PyPDFLoader(doc).load()
    full_doc = '\n'.join([page.page_content for page in loaded_doc])
    return full_doc

# %%
#Caricamento dei menù
anima_cosmica_docs = full_doc('Hackapizza Dataset/Menu/Anima Cosmica.pdf')
armonia_universale_docs = full_doc('Hackapizza Dataset/Menu/Armonia Universale.pdf')
cosmica_essenza_docs = full_doc('Hackapizza Dataset/Menu/Cosmica Essenza.pdf')
datapizza_docs = full_doc('Hackapizza Dataset/Menu/Datapizza.pdf')
eco_di_pandora_docs = full_doc('Hackapizza Dataset/Menu/Eco di Pandora.pdf')
eredita_galattica_docs = full_doc('Hackapizza Dataset/Menu/Eredita Galattica.pdf')
essenza_dell_infinito_docs = full_doc('Hackapizza Dataset/Menu/Essenza dell Infinito.pdf')
il_firmamento_docs = full_doc('Hackapizza Dataset/Menu/Il Firmamento.pdf')
l_architetto_dell_universo_docs = full_doc('Hackapizza Dataset/Menu/L Architetto dell Universo.pdf')
l_eco_dei_sapori_docs = full_doc('Hackapizza Dataset/Menu/L Eco dei Sapori.pdf')
l_equilibrio_quantico_docs = full_doc('Hackapizza Dataset/Menu/L Equilibrio Quantico.pdf')
l_essenza_cosmica_docs = full_doc('Hackapizza Dataset/Menu/L Essenza Cosmica.pdf')
l_essenza_del_multiverso_su_pandora_docs = full_doc('Hackapizza Dataset/Menu/L Essenza del Multiverso su Pandora.pdf')
l_essenza_delle_dune_docs = full_doc('Hackapizza Dataset/Menu/L Essenza delle Dune.pdf')
l_essenza_di_asgard_docs = full_doc('Hackapizza Dataset/Menu/L Essenza di Asgard.pdf')
l_etere_del_gusto_docs = full_doc('Hackapizza Dataset/Menu/L Etere del Gusto.pdf')
l_oasi_delle_dune_stellari_docs = full_doc('Hackapizza Dataset/Menu/L Oasi delle Dune Stellari.pdf')
l_universo_in_cucina_docs = full_doc('Hackapizza Dataset/Menu/L Universo in Cucina.pdf')
l_infinito_in_un_boccone_docs = full_doc('Hackapizza Dataset/Menu/L infinito in un Boccone.pdf')
le_dimensioni_del_gusto_docs = full_doc('Hackapizza Dataset/Menu/Le Dimensioni del Gusto.pdf')
le_stelle_danzanti_docs = full_doc('Hackapizza Dataset/Menu/Le Stelle Danzanti.pdf')
le_stelle_che_ballano_docs = full_doc('Hackapizza Dataset/Menu/Le Stelle che Ballano.pdf')
ristorante_quantico_docs = full_doc('Hackapizza Dataset/Menu/Ristorante Quantico.pdf')
ristorante_delle_dune_stellari_docs = full_doc('Hackapizza Dataset/Menu/Ristorante delle Dune Stellari.pdf')
sala_del_valhalla_docs = full_doc('Hackapizza Dataset/Menu/Sala del Valhalla.pdf')
sapore_del_dune_docs = full_doc('Hackapizza Dataset/Menu/Sapore del Dune.pdf')
stelle_astrofisiche_docs = full_doc('Hackapizza Dataset/Menu/Stelle Astrofisiche.pdf')
stelle_dell_infinito_celestiale_docs = full_doc('Hackapizza Dataset/Menu/Stelle dell Infinito Celestiale.pdf')
tutti_a_tarsvola_docs = full_doc('Hackapizza Dataset/Menu/Tutti a TARSvola.pdf')
universo_gastronomico_di_namecc_docs = full_doc('Hackapizza Dataset/Menu/Universo Gastronomico di Namecc.pdf')

# %%
# Creazione dei riassunti
summarizer_model = ChatOpenAI(temperature=0.7, model='gpt-4o')
menu_summarizer_prompt = PromptTemplate(
    template = '''
    Il tuo compito è convertire un insieme di menù in un file CSV con le seguenti colonne:

    Nome ristorante → Nome del ristorante.
    Nome chef → Nome dello chef responsabile del menù.
    Licenze ottenute con punteggio → Lista delle licenze ottenute dallo chef o dal ristorante, includendo solo quelle valide e convertendo i livelli in numeri arabi (es. "II" → 2).
    Nome piatto → Nome del piatto.
    Ingredienti del piatto → Lista di ingredienti utilizzati.
    Tecniche per cucinare il piatto → Lista delle tecniche impiegate per la preparazione del piatto.
    Pianeta → Pianeta di origine del ristorante.
    Regole di Formattazione:
    Colonna "Licenze ottenute con punteggio"

    Devono essere esclusivamente tra le seguenti:
    Psionica (P)
    Temporale (t)
    Gravitazionale (G)
    Antimateria (e+)
    Magnetica (Mx)
    Quantistica (Q)
    Luce (c)
    Livello di Sviluppo Tecnologico (LTK)
    Se i livelli delle licenze sono espressi in numeri romani, convertirli in numeri arabi.
    Esempio di riga finale:
    Anima Cosmica,Aurora Stellaris,"""Psionica 3"", ""Temporale 1"", ""Gravitazionale 1"", ""Antimateria 1"", ""Quantistica 16"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 2""",Nebulosa Celestiale alla Stellaris,"""Shard di Materia Oscura"", ""Carne di Balena spaziale"", ""Carne di Mucca"", ""Teste di Idra"", ""Riso di Cassandra"", ""Biscotti della Galassia"", ""Pane di Luce"", ""Funghi dell’Etere"", ""Spezie Melange""","""Cottura a Vapore con Flusso di Particelle Isoarmoniche"", ""Cottura a Vapore Termocinetica Multipla"", ""Taglio a Risonanza Sonica Rigenerativa"", ""Cottura con Microonde Entropiche Sincronizzate""",Pandora
    Anima Cosmica,Aurora Stellaris,"""Psionica 3"", ""Temporale 1"", ""Gravitazionale 1"", ""Antimateria 1"", ""Quantistica 16"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 2""",Sinfonia Cosmica ma Fatta Male,"""Polvere di Pulsar"", ""Radici di Singolarità"", ""Lattuga Namecciana"", ""Baccacedro"", ""Granuli di Nebbia Arcobaleno"", ""Funghi dell’Etere"", ""Erba Pipa""","""Affumicatura a Stratificazione Quantica"", ""Cottura a Forno Dinamico Inversionale""",Pandora

    Non utilizzare parentesi quadre per le liste.
    Numeri e Formattazione

    I livelli delle licenze devono essere numeri arabi.
    Le liste devono essere separate correttamente nel CSV senza perdere formattazione.
    
    Ecco il menù: {menu}
    ''',
    input_variables = ['menu']
)

menu_summarizer = menu_summarizer_prompt | summarizer_model | StrOutputParser()

# %%
# Creazione CSV
galaxy_menus = [
    anima_cosmica_docs, armonia_universale_docs, cosmica_essenza_docs, datapizza_docs,
    eco_di_pandora_docs, eredita_galattica_docs, essenza_dell_infinito_docs, il_firmamento_docs,
    l_architetto_dell_universo_docs, l_eco_dei_sapori_docs, l_equilibrio_quantico_docs, l_essenza_cosmica_docs,
    l_essenza_del_multiverso_su_pandora_docs, l_essenza_delle_dune_docs, l_essenza_di_asgard_docs,
    l_etere_del_gusto_docs, l_oasi_delle_dune_stellari_docs, l_universo_in_cucina_docs, l_infinito_in_un_boccone_docs,
    le_dimensioni_del_gusto_docs, le_stelle_danzanti_docs, le_stelle_che_ballano_docs, ristorante_quantico_docs,
    ristorante_delle_dune_stellari_docs, sala_del_valhalla_docs, sapore_del_dune_docs, stelle_astrofisiche_docs,
    stelle_dell_infinito_celestiale_docs, tutti_a_tarsvola_docs, universo_gastronomico_di_namecc_docs
]
tot_csv = 0
csvs = []

for menu in galaxy_menus:
    csv_file = menu_summarizer.invoke({'menu':menu})
    csvs.append(csv_file)
    tot_csv += 1
    print(tot_csv)

# %%
for x in csvs:
    print(x)
    print('-'*100)
# Out:
# Ecco il file CSV con le informazioni richieste:
#
# ```csv
# Nome ristorante,Nome chef,Licenze ottenute con punteggio,Nome piatto,Ingredienti del piatto,Tecniche per cucinare il piatto,Pianeta
# Anima Cosmica,Aurora Stellaris,"""Psionica 3"", ""Temporale 1"", ""Gravitazionale 1"", ""Antimateria 1"", ""Quantistica 16"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 2""",Nebulosa Celestiale alla Stellaris,"""Shard di Materia Oscura"", ""Carne di Balena spaziale"", ""Carne di Mucca"", ""Teste di Idra"", ""Riso di Cassandra"", ""Biscotti della Galassia"", ""Pane di Luce"", ""Funghi dell’Etere"", ""Spezie Melange""","""Cottura a Vapore con Flusso di Particelle Isoarmoniche"", ""Cottura a Vapore Termocinetica Multipla"", ""Taglio a Risonanza Sonica Rigenerativa"", ""Cottura con Microonde Entropiche Sincronizzate""",Pandora
# Anima Cosmica,Aurora Stellaris,"""Psionica 3"", ""Temporale 1"", ""Gravitazionale 1"", ""Antimateria 1"", ""Quantistica 16"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 2""",Sinfonia Cosmica ma Fatta Male,"""Polvere di Pulsar"", ""Radici di Singolarità"", ""Lattuga Namecciana"", ""Baccacedro"", ""Granuli di Nebbia Arcobaleno"", ""Funghi dell’Etere"", ""Erba Pipa""","""Affumicatura a Stratificazione Quantica"", ""Cottura a Forno Dinamico Inversionale""",Pandora
# Anima Cosmica,Aurora Stellaris,"""Psionica 3"", ""Temporale 1"", ""Gravitazionale 1"", ""Antimateria 1"", ""Quantistica 16"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 2""",Astro-Risotto alle Onde Temporali,"""Polvere di Pulsar"", ""Foglie di Nebulosa"", ""Radici di Singolarità"", ""Baccacedro"", ""Sale Temporale""","""Saltare in Padella Classica"", ""Marinatura tramite Reazioni d'Antimateria Diluite""",Pandora
# Anima Cosmica,Aurora Stellaris,"""Psionica 3"", ""Temporale 1"", ""Gravitazionale 1"", ""Antimateria 1"", ""Quantistica 16"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 2""",Sinfonia Galattica alla Griglia Cangiante,"""Shard di Materia Oscura"", ""Teste di Idra"", ""Amido di Stellarion"", ""Fusilli del Vento"", ""Spore Quantiche"", ""Erba Pipa""","""Congelamento Bio-Luminiscente Sincronico"", ""Sinergia Elettro-Osmotica Programmabile"", ""Bollitura Infrasonica Armonizzata"", ""Marinatura a Infusione Gravitazionale"", ""Grigliatura Eletro-Molecolare a Spaziatura Variabile""",Pandora
# Anima Cosmica,Aurora Stellaris,"""Psionica 3"", ""Temporale 1"", ""Gravitazionale 1"", ""Antimateria 1"", ""Quantistica 16"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 2""",Galassie Infiammate: Sinfonia Cosmica in Sei Dimensioni,"""Frammenti di Supernova"", ""Uova di Fenice"", ""Carne di Mucca"", ""Riso di Cassandra"", ""Spaghi del Sole"", ""Biscotti della Galassia"", ""Lacrime di Unicorno"", ""Nduja Fritta Tanto""","""Cottura a Vapore Ecodinamico Bilanciato"", ""Cottura Idrodinamica Autoregolante"", ""Marinatura tramite Reazioni d'Antimateria Diluite"", ""Bollitura Termografica a Rotazione Veloce""",Pandora
# Anima Cosmica,Aurora Stellaris,"""Psionica 3"", ""Temporale 1"", ""Gravitazionale 1"", ""Antimateria 1"", ""Quantistica 16"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 2""",Galassie Sospese: Un Viaggio di Sapori Cosmogalattici,"""Cristalli di Memoria"", ""Radici di Gravità"", ""Pane degli Abissi"", ""Biscotti della Galassia"", ""Lacrime di Unicorno"", ""Nduja Fritta Tanto""","""Affumicatura a Stratificazione Quantica"", ""Cottura a Vapore Termocinetica Multipla"", ""Marinatura Temporale Sincronizzata""",Pandora
# Anima Cosmica,Aurora Stellaris,"""Psionica 3"", ""Temporale 1"", ""Gravitazionale 1"", ""Antimateria 1"", ""Quantistica 16"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 2""",Pioggia di Andromeda,"""Cristalli di Memoria"", ""Lattuga Namecciana"", ""Radici di Singolarità"", ""Carne di Kraken"", ""Uova di Fenice"", ""Fibra di Sintetex"", ""Fusilli del Vento"", ""Lacrime di Andromeda"", ""Essenza di Speziaria""","""Bollitura Termografica a Rotazione Veloce"", ""Bollitura Infrasonica Armonizzata"", ""Cottura Idrodinamica Autoregolante"", ""Sinergia Elettro-Osmotica Programmabile"", ""Marinatura Temporale Sincronizzata""",Pandora
# Anima Cosmica,Aurora Stellaris,"""Psionica 3"", ""Temporale 1"", ""Gravitazionale 1"", ""Antimateria 1"", ""Quantistica 16"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 2""",Sinfonia Cosmica ma Fatta Bene,"""Shard di Materia Oscura"", ""Colonia di Mycoflora"", ""Carne di Balena spaziale"", ""Amido di Stellarion"", ""Nettare di Sirena"", ""Petali di Eco""","""Affumicatura Temporale Risonante"", ""Congelamento Bio-Luminiscente Sincronico"", ""Bollitura Infrasonica Armonizzata"", ""Impasto Gravitazionale Vorticoso""",Pandora
# Anima Cosmica,Aurora Stellaris,"""Psionica 3"", ""Temporale 1"", ""Gravitazionale 1"", ""Antimateria 1"", ""Quantistica 16"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 2""",Odissea Cosmica di Nettuno,"""Pane di Luce"", ""Farina di Nettuno"", ""Amido di Stellarion"", ""Nettare di Sirena"", ""Essenza di Vuoto""","""Bollitura Infrasonica Armonizzata"", ""Cottura Sottovuoto Frugale Energeticamente Negativa"", ""Bollitura Termografica a Rotazione Veloce""",Pandora
# Anima Cosmica,Aurora Stellaris,"""Psionica 3"", ""Temporale 1"", ""Gravitazionale 1"", ""Antimateria 1"", ""Quantistica 16"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 2""",Galassia Commovente di Stellari,"""Polvere di Stelle"", ""Alghe Bioluminescenti"", ""Baccacedro"", ""Carne di Balena spaziale"", ""Teste di Idra"", ""Fibra di Sintetex"", ""Funghi Orbitali"", ""Essenza di Tachioni""","""Grigliatura Eletro-Molecolare a Spaziatura Variabile"", ""Marinatura a Infusione Gravitazionale"", ""Cryo-Tessitura Energetica Polarizzata""",Pandora
# ```
#
# Assicurati di copiare il contenuto tra i delimitatori ``` e inserirlo in un file CSV per l'importazione e la visualizzazione corretta.
# ----------------------------------------------------------------------------------------------------
# Ecco il file CSV creato sulla base del menù fornito:
#
# ```csv
# Nome ristorante,Nome chef,Licenze ottenute con punteggio,Nome piatto,Ingredienti del piatto,Tecniche per cucinare il piatto,Pianeta
# Armonia Universale,Maestro Alessandro Stellanova,"Psionica 1, Gravitazionale 1, Magnetica 1, Quantistica 8, Luce 2, Livello di Sviluppo Tecnologico 5",Sinfonia Cosmica: Versione Pizza,"Polvere di Pulsar, Radici di Gravità, Radici di Singolarità, Spaghi del Sole, Riso di Cassandra, Farina di Nettuno, Funghi Orbitali, Spezie Melange, Cioccorane","Amalgamazione Sintetica Molecolare, Cottura a Vapore con Flusso di Particelle Isoarmoniche, Impasto Gravitazionale Vorticoso",Pandora
# Armonia Universale,Maestro Alessandro Stellanova,"Psionica 1, Gravitazionale 1, Magnetica 1, Quantistica 8, Luce 2, Livello di Sviluppo Tecnologico 5",Galassia di Sapore Interstellare,"Frammenti di Supernova, Colonia di Mycoflora, Foglie di Nebulosa, Carne di Mucca, Fibra di Sintetex, Carne di Kraken, Spaghi del Sole, Nettare di Sirena, Spezie Melange, Burrobirra","Impasto a Campi Magnetici Dualistici, Decostruzione Magnetica Risonante, Amalgamazione Sintetica Molecolare, Bollitura Infrasonica Armonizzata",Pandora
# Armonia Universale,Maestro Alessandro Stellanova,"Psionica 1, Gravitazionale 1, Magnetica 1, Quantistica 8, Luce 2, Livello di Sviluppo Tecnologico 5",Sinfonia Cosmica di Sapore,"Shard di Materia Oscura, Carne di Xenodonte, Fibra di Sintetex, Farina di Nettuno, Granuli di Nebbia Arcobaleno, Nduja Fritta Tanto, Ravioli al Vaporeon","Idro-Cristallizzazione Sonora Quantistica, Saltare in Padella Realtà Energetiche Parallele, Sferificazione tramite Matrici Biofotiche, Affumicatura a Stratificazione Quantica, Sferificazione con Campi Magnetici Entropici",Pandora
# Armonia Universale,Maestro Alessandro Stellanova,"Psionica 1, Gravitazionale 1, Magnetica 1, Quantistica 8, Luce 2, Livello di Sviluppo Tecnologico 5",Sinfonia Cosmica di Luminiscenze e Contrasti,"Uova di Fenice, Carne di Drago, Carne di Kraken, Amido di Stellarion, Riso di Cassandra, Spezie Melange, Slurm","Ebollizione Magneto-Cinetica Pulsante, Grigliatura Eletro-Molecolare a Spaziatura Variabile",Pandora
# Armonia Universale,Maestro Alessandro Stellanova,"Psionica 1, Gravitazionale 1, Magnetica 1, Quantistica 8, Luce 2, Livello di Sviluppo Tecnologico 5",Sinfonia Cosmica in Otto Movimenti,"Frammenti di Supernova, Foglie di Nebulosa, Alghe Bioluminescenti, Fibra di Sintetex, Carne di Mucca, Gnocchi del Crepuscolo, Lacrime di Andromeda, Spezie Melange","Sferificazione con Campi Magnetici Entropici, Saltare in Padella Classica, Bollitura Termografica a Rotazione Veloce, Grigliatura Eletro-Molecolare a Spaziatura Variabile",Pandora
# Armonia Universale,Maestro Alessandro Stellanova,"Psionica 1, Gravitazionale 1, Magnetica 1, Quantistica 8, Luce 2, Livello di Sviluppo Tecnologico 5",Portale Cosmico: Sinfonia di Gnocchi del Crepuscolo con Essenza di Tachioni e Sfumature di Fenice,"Shard di Materia Oscura, Uova di Fenice, Gnocchi del Crepuscolo, Plasma Vitale, Essenza di Tachioni","Bollitura Infrasonica Armonizzata, Cottura a Vapore Ecodinamico Bilanciato, Decostruzione Magnetica Risonante, Cottura a Vapore con Flusso di Particelle Isoarmoniche, Affumicatura Polarizzata a Freddo Iperbarico",Pandora
# Armonia Universale,Maestro Alessandro Stellanova,"Psionica 1, Gravitazionale 1, Magnetica 1, Quantistica 8, Luce 2, Livello di Sviluppo Tecnologico 5",Sinfonia Cosmica: Versione Data,"Polvere di Stelle, Radici di Gravità, Colonia di Mycoflora, Fusilli del Vento, Pane degli Abissi, Essenza di Tachioni","Cottura a Vapore Termocinetica Multipla, Affumicatura a Stratificazione Quantica, Fermentazione Psionica Energetica",Pandora
# Armonia Universale,Maestro Alessandro Stellanova,"Psionica 1, Gravitazionale 1, Magnetica 1, Quantistica 8, Luce 2, Livello di Sviluppo Tecnologico 5",Sinfonia Cosmologica,"Shard di Materia Oscura, Radici di Gravità, Foglie di Nebulosa, Biscotti della Galassia, Essenza di Vuoto","Affettamento a Pulsazioni Quantistiche, Cottura Sottovuoto Pulsar Magnetica, Marinatura Sotto Zero a Polarità Inversa, Grigliatura Eletro-Molecolare a Spaziatura Variabile",Pandora
# Armonia Universale,Maestro Alessandro Stellanova,"Psionica 1, Gravitazionale 1, Magnetica 1, Quantistica 8, Luce 2, Livello di Sviluppo Tecnologico 5",Sinfonia Cosmica di Armonie Terrestri e Celesti,"Cristalli di Memoria, Uova di Fenice, Carne di Kraken, Fibra di Sintetex, Granuli di Nebbia Arcobaleno, Lacrime di Andromeda, Spezie Melange","Sferificazione tramite Matrici Biofotiche, Idro-Cristallizzazione Sonora Quantistica, Affettamento a Pulsazioni Quantistiche, Cottura Sottovuoto Pulsar Magnetica",Pandora
# Armonia Universale,Maestro Alessandro Stellanova,"Psionica 1, Gravitazionale 1, Magnetica 1, Quantistica 8, Luce 2, Livello di Sviluppo Tecnologico 5",Cosmo Sferico di Sogni Rigenerativi,"Radici di Gravità, Baccacedro, Lattuga Namecciana, Teste di Idra, Carne di Xenodonte, Farina di Nettuno, Nettare di Sirena","Sferificazione con Campi Magnetici Entropici, Cottura a Vapore Ecodinamico Bilanciato, Congelamento Bio-Luminiscente Sincronico",Pandora
# ```
#
# Questo file CSV rispetta tutte le specifiche fornite nel compito, convertendo i numeri romani in numeri arabi e assicurando che le licenze e gli ingredienti siano formattati correttamente.
# ----------------------------------------------------------------------------------------------------
# Ecco la conversione del menù fornito in formato CSV:
#
# ```csv
# Nome ristorante,Nome chef,Licenze ottenute con punteggio,Nome piatto,Ingredienti del piatto,Tecniche per cucinare il piatto,Pianeta
# Cosmica Essenza,Aurelio "Starweaver" Celestini,"""Psionica 5"", ""Quantistica 9"", ""Gravitazionale 3"", ""Antimateria 1"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 3""",Galassie in Epifania: Risotto Celestiale con Preziosi dell'Universo,"""Polvere di Pulsar"", ""Carne di Xenodonte"", ""Carne di Balena spaziale"", ""Teste di Idra"", ""Spaghi del Sole"", ""Riso di Cassandra"", ""Farina di Nettuno"", ""Lacrime di Andromeda"", ""Petali di Eco""","""Marinatura a Infusione Gravitazionale"", ""Cryo-Tessitura Energetica Polarizzata"", ""Saltare in Padella Classica"", ""Cottura Olografica Quantum Fluttuante""",Tatooine
# Cosmica Essenza,Aurelio "Starweaver" Celestini,"""Psionica 5"", ""Quantistica 9"", ""Gravitazionale 3"", ""Antimateria 1"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 3""",Galassia Suprema,"""Shard di Prisma Stellare"", ""Foglie di Nebulosa"", ""Carne di Drago"", ""Carne di Mucca"", ""Fibra di Sintetex"", ""Lacrime di Unicorno"", ""Essenza di Tachioni""","""Idro-Cristallizzazione Sonora Quantistica"", ""Cottura Sottovuoto Antimateria"", ""Taglio a Risonanza Sonica Rigenerativa"", ""Bollitura Infrasonica Armonizzata""",Tatooine
# Cosmica Essenza,Aurelio "Starweaver" Celestini,"""Psionica 5"", ""Quantistica 9"", ""Gravitazionale 3"", ""Antimateria 1"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 3""",Fusione Celeste,"""Radici di Singolarità"", ""Foglie di Nebulosa"", ""Colonia di Mycoflora"", ""Carne di Mucca"", ""Carne di Kraken"", ""Riso di Cassandra"", ""Fusilli del Vento"", ""Biscotti della Galassia"", ""Spore Quantiche"", ""Essenza di Speziaria""","""Cryo-Tessitura Energetica Polarizzata"", ""Sferificazione a Gravità Psionica Variabile"", ""Bollitura Termografica a Rotazione Veloce""",Tatooine
# Cosmica Essenza,Aurelio "Starweaver" Celestini,"""Psionica 5"", ""Quantistica 9"", ""Gravitazionale 3"", ""Antimateria 1"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 3""",Sinfonia Cosmica di Andromeda,"""Foglie di Mandragora"", ""Radici di Singolarità"", ""Riso di Cassandra"", ""Lacrime di Andromeda"", ""Petali di Eco""","""Cottura Sottovuoto Antimateria"", ""Sferificazione a Gravità Psionica Variabile""",Tatooine
# Cosmica Essenza,Aurelio "Starweaver" Celestini,"""Psionica 5"", ""Quantistica 9"", ""Gravitazionale 3"", ""Antimateria 1"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 3""",Risveglio Cosmico: Una Sinfonia di Sapori Universali,"""Shard di Prisma Stellare"", ""Lattuga Namecciana"", ""Carne di Mucca"", ""Fibra di Sintetex"", ""Amido di Stellarion"", ""Riso di Cassandra"", ""Muffa Lunare"", ""Erba Pipa""","""Grigliatura Psionica Dinamica Ritmica"", ""Cottura a Vapore Ecodinamico Bilanciato""",Tatooine
# Cosmica Essenza,Aurelio "Starweaver" Celestini,"""Psionica 5"", ""Quantistica 9"", ""Gravitazionale 3"", ""Antimateria 1"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 3""",Galassia Incantata: Un Viaggio Attraverso l'Infinito,"""Shard di Materia Oscura"", ""Carne di Xenodonte"", ""Teste di Idra"", ""Fibra di Sintetex"", ""Riso di Cassandra"", ""Pane di Luce"", ""Pane degli Abissi"", ""Nduja Fritta Tanto""","""Grigliatura Psionica Dinamica Ritmica"", ""Cottura a Forno Dinamico Inversionale"", ""Cottura a Vapore Risonante Simbiotico""",Tatooine
# Cosmica Essenza,Aurelio "Starweaver" Celestini,"""Psionica 5"", ""Quantistica 9"", ""Gravitazionale 3"", ""Antimateria 1"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 3""",Sinfonia Celestiale di Echi Galattici,"""Baccacedro"", ""Fibra di Sintetex"", ""Carne di Balena spaziale"", ""Carne di Kraken"", ""Lacrime di Unicorno""","""Cottura Idrodinamica Autoregolante"", ""Fermentazione Psionica Energetica"", ""Affettamento a Pulsazioni Quantistiche"", ""Decostruzione Atomica a Strati Energetici"", ""Cottura con Microonde Entropiche Sincronizzate""",Tatooine
# Cosmica Essenza,Aurelio "Starweaver" Celestini,"""Psionica 5"", ""Quantistica 9"", ""Gravitazionale 3"", ""Antimateria 1"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 3""",Porta Celestiale alle Stelle,"""Vero Ghiaccio"", ""Liane di Plasmodio"", ""Carne di Kraken"", ""Teste di Idra"", ""Funghi dell’Etere"", ""Erba Pipa""","""Bollitura Entropica Sincronizzata"", ""Cottura Sottovuoto Frugale Energeticamente Negativa"", ""Marinatura a Infusione Gravitazionale""",Tatooine
# Cosmica Essenza,Aurelio "Starweaver" Celestini,"""Psionica 5"", ""Quantistica 9"", ""Gravitazionale 3"", ""Antimateria 1"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 3""",Sinfonia Celeste dell'Equilibrio Temporale,"""Polvere di Crononite"", ""Carne di Balena spaziale"", ""Carne di Mucca"", ""Uova di Fenice"", ""Funghi dell’Etere"", ""Spezie Melange""","""Idro-Cristallizzazione Sonora Quantistica"", ""Cryo-Tessitura Energetica Polarizzata"", ""Sinergia Elettro-Osmotica Programmabile""",Tatooine
# Cosmica Essenza,Aurelio "Starweaver" Celestini,"""Psionica 5"", ""Quantistica 9"", ""Gravitazionale 3"", ""Antimateria 1"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 3""",Il Risveglio delle Stelle,"""Polvere di Stelle"", ""Baccacedro"", ""Carne di Balena spaziale"", ""Biscotti della Galassia"", ""Pane degli Abissi"", ""Muffa Lunare""","""Marinatura a Infusione Gravitazionale"", ""Marinatura tramite Reazioni d'Antimateria Diluite""",Tatooine
# ```
#
# Note:
# - Ho convertito i livelli delle licenze da numeri romani a numeri arabi.
# - Ho incluso solo le licenze valide e ho formato le liste di ingredienti e tecniche secondo le istruzioni.
# ----------------------------------------------------------------------------------------------------
# Ecco il file CSV con le informazioni estratte dal menù del ristorante "L'Infinito Sapore":
#
# ```csv
# Nome ristorante,Nome chef,Licenze ottenute con punteggio,Nome piatto,Ingredienti del piatto,Tecniche per cucinare il piatto,Pianeta
# "L'Infinito Sapore","Alessandro-Pierpaolo-Jack Quantum","""Quantistica 11"", ""Temporale 2"", ""Antimateria 1"", ""Magnetica 1"", ""Luce 1"", ""Livello di Sviluppo Tecnologico 9""","Pizza Fra","""Amido di Stellarion"", ""Fibra di Sintetex"", ""Vero Ghiaccio"", ""Radici di Gravità"", ""Baccacedro"", ""Farina di Nettuno"", ""Salsa Szechuan""","""Forno Dinamico Inversionale"", ""Affettamento a Pulsazioni Quantistiche"", ""Marinatura Temporale Sincronizzata"", ""Fermentazione Quantico Biometrica"", ""Ebollizione Magneto-Cinetica Pulsante""",Pandora
# "L'Infinito Sapore","Alessandro-Pierpaolo-Jack Quantum","""Quantistica 11"", ""Temporale 2"", ""Antimateria 1"", ""Magnetica 1"", ""Luce 1"", ""Livello di Sviluppo Tecnologico 9""","Pizza Gio","""Pane di Luce"", ""Cristalli di Memoria"", ""Lacrime di Andromeda"", ""Radici di Gravità"", ""Liane di Plasmodio"", ""Erba Pipa""","""Sferificazione Filamentare a Molecole Vibrazionali"", ""Affumicatura Temporale Risonante"", ""Idro-Cristallizzazione Sonora Quantistica"", ""Marinatura tramite Reazioni d'Antimateria Diluite""",Pandora
# "L'Infinito Sapore","Alessandro-Pierpaolo-Jack Quantum","""Quantistica 11"", ""Temporale 2"", ""Antimateria 1"", ""Magnetica 1"", ""Luce 1"", ""Livello di Sviluppo Tecnologico 9""","Pizza Emma","""Liane di Plasmodio"", ""Polvere di Stelle"", ""Colonia di Mycoflora"", ""Funghi dell'Etere"", ""Foglie di Mandragora"", ""Essenza di Speziaria""","""Affettamento a Pulsazioni Quantistiche"", ""Grigliatura Elettro-Molecolare a Spaziatura Variabile"", ""Microonde Entropiche Sincronizzate"", ""Idro-Cristallizzazione Sonora Quantistica"", ""Congelazione Iperdimensionalmente Stratificata""",Pandora
# "L'Infinito Sapore","Alessandro-Pierpaolo-Jack Quantum","""Quantistica 11"", ""Temporale 2"", ""Antimateria 1"", ""Magnetica 1"", ""Luce 1"", ""Livello di Sviluppo Tecnologico 9""","Pizza Luca","""Alghe Bioluminescenti"", ""Gnocchi del Crepuscolo"", ""Pane degli Abissi"", ""Salsa Szechuan"", ""Funghi Orbitali"", ""Farina di Nettuno""","""Sinergia Elettro-Osmotica Programmabile"", ""Cottura a Vapore Ecodinamico Bilanciato"", ""Marinatura Sotto Zero a Polarità Inversa"", ""Forno Dinamico Inversionale"", ""Bollitura Termografica a Rotazione Veloce""",Pandora
# "L'Infinito Sapore","Alessandro-Pierpaolo-Jack Quantum","""Quantistica 11"", ""Temporale 2"", ""Antimateria 1"", ""Magnetica 1"", ""Luce 1"", ""Livello di Sviluppo Tecnologico 9""","Pizza Raul","""Teste di Idra"", ""Riso di Cassandra"", ""Amido di Stellarion"", ""Farina di Nettuno"", ""Spore Quantiche"", ""Essenza di Vuoto""","""Cottura a Forno Dinamico Inversionale"", ""Marinatura Sotto Zero a Polarità Inversa"", ""Decostruzione Magnetica Risonante"", ""Affumicatura a Stratificazione Quantica""",Pandora
# "L'Infinito Sapore","Alessandro-Pierpaolo-Jack Quantum","""Quantistica 11"", ""Temporale 2"", ""Antimateria 1"", ""Magnetica 1"", ""Luce 1"", ""Livello di Sviluppo Tecnologico 9""","Pizza Cri","""Fusilli del Vento"", ""Granuli di Nebbia Arcobaleno"", ""Funghi dell'Etere"", ""Essenza di Speziaria"", ""Cristalli di Memoria"", ""Radici di Gravità e Singolarità"", ""Uova di Fenice""","""Affumicatura a Stratificazione Quantica"", ""Sferificazione con Campi Magnetici Entropici"", ""Microonde Entropiche Sincronizzate""",Pandora
# "L'Infinito Sapore","Alessandro-Pierpaolo-Jack Quantum","""Quantistica 11"", ""Temporale 2"", ""Antimateria 1"", ""Magnetica 1"", ""Luce 1"", ""Livello di Sviluppo Tecnologico 9""","Pizza Baby Daniele","""Spaghi del Sole"", ""Carne di Balena Spaziale"", ""Lacrime di Andromeda"", ""Spezie Melange"", ""Foglie di Nebulosa"", ""Radici di Singolarità"", ""Uova di Fenice"", ""Biscotti della Galassia"", ""Frammenti di Supernova""","""Cottura a Vapore Termocinetica Multipla"", ""Bollitura Termografica a Rotazione Veloce"", ""Grigliatura Elettro-Molecolare a Spaziatura Variabile"", ""Congelazione Iperdimensionalmente Stratificata"", ""Bollitura Entropica Sincronizzata""",Pandora
# "L'Infinito Sapore","Alessandro-Pierpaolo-Jack Quantum","""Quantistica 11"", ""Temporale 2"", ""Antimateria 1"", ""Magnetica 1"", ""Luce 1"", ""Livello di Sviluppo Tecnologico 9""","Pizza Baby Lorenzo","""Riso di Cassandra"", ""Carne di Balena Spaziale"", ""Carne di Drago"", ""Radici di Gravità"", ""Sale Temporale"", ""Uova di Fenice"", ""Baccacedro"", ""Pane di Luce"", ""Frammenti di Supernova"", ""Lacrime di Andromeda""","""Bollitura Entropica Sincronizzata"", ""Amalgamazione Sintetica Molecolare""",Pandora
# "L'Infinito Sapore","Alessandro-Pierpaolo-Jack Quantum","""Quantistica 11"", ""Temporale 2"", ""Antimateria 1"", ""Magnetica 1"", ""Luce 1"", ""Livello di Sviluppo Tecnologico 9""","Pizza Baby Simone e Alessandro","""Fusilli del Vento"", ""Spaghi del Sole"", ""Nduja Fritta Tanto"", ""Radici di Singolarità"", ""Carne di Xenodonte"", ""Pane di Luce"", ""Lattuga Namecciana"", ""Baccacedro"", ""Crononite""","""Taglio a Risonanza Sonica Rigenerativa"", ""Forno Dinamico Inversionale"", ""Bollitura Termografica a Rotazione Veloce"", ""Cryo-Tessitura Energetica Polarizzata"", ""Decostruzione Interdimensionale Lovecraftiana""",Pandora
# ```
#
# Note:
# - Le licenze sono state convertite in numeri arabi e filtrate secondo le specifiche.
# - Le liste di ingredienti e tecniche sono state formattate correttamente nel formato CSV con virgolette doppie.
# - I dettagli come il nome del ristorante e del pianeta sono stati mantenuti per ogni voce.
# ----------------------------------------------------------------------------------------------------
# Ecco il file CSV convertito dai menù forniti:
#
# ```csv
# Nome ristorante,Nome chef,Licenze ottenute con punteggio,Nome piatto,Ingredienti del piatto,Tecniche per cucinare il piatto,Pianeta
# L'Eco di Pandora,Alessandra Novastella,"""Psionica 3"", ""Temporale 1"", ""Gravitazionale 1"", ""Antimateria 1"", ""Magnetica 1"", ""Quantistica 3"", ""Luce 1"", ""Livello di Sviluppo Tecnologico 6""",Serenata del Multiverso,"""Frammenti di Supernova"", ""Liane di Plasmodio"", ""Carne di Balena spaziale"", ""Fibra di Sintetex"", ""Nettare di Sirena"", ""Essenza di Speziaria""","""Cottura Sottovuoto Multirealità Collassante"", ""Sferificazione Filamentare a Molecole Vibrazionali"", ""Grigliatura Psionica Dinamica Ritmica"", ""Cottura a Forno Dinamico Inversionale"", ""Taglio a Risonanza Sonica Rigenerativa""",Pandora
# L'Eco di Pandora,Alessandra Novastella,"""Psionica 3"", ""Temporale 1"", ""Gravitazionale 1"", ""Antimateria 1"", ""Magnetica 1"", ""Quantistica 3"", ""Luce 1"", ""Livello di Sviluppo Tecnologico 6""",Euforia Cosmica,"""Vero Ghiaccio"", ""Radici di Singolarità"", ""Alghe Bioluminescenti"", ""Carne di Drago"", ""Uova di Fenice"", ""Funghi dell’Etere"", ""Essenza di Vuoto""","""Grigliatura Eletro-Molecolare a Spaziatura Variabile"", ""Amalgamazione Sintetica Molecolare"", ""Surgelamento Antimaterico a Risonanza Inversa""",Pandora
# L'Eco di Pandora,Alessandra Novastella,"""Psionica 3"", ""Temporale 1"", ""Gravitazionale 1"", ""Antimateria 1"", ""Magnetica 1"", ""Quantistica 3"", ""Luce 1"", ""Livello di Sviluppo Tecnologico 6""",Galassie Riflesse: Sinfonia del Multiverso,"""Polvere di Pulsar"", ""Radici di Singolarità"", ""Liane di Plasmodio"", ""Carne di Drago"", ""Teste di Idra"", ""Carne di Mucca"", ""Pane di Luce"", ""Gnocchi del Crepuscolo"", ""Riso di Cassandra"", ""Funghi dell’Etere"", ""Sale Temporale""","""Cottura Olografica Quantum Fluttuante"", ""Cottura a Vapore Termocinetica Multipla"", ""Affumicatura tramite Big Bang Microcosmico"", ""Marinatura tramite Reazioni d'Antimateria Diluite"", ""Cottura a Vapore Ecodinamico Bilanciato""",Pandora
# L'Eco di Pandora,Alessandra Novastella,"""Psionica 3"", ""Temporale 1"", ""Gravitazionale 1"", ""Antimateria 1"", ""Magnetica 1"", ""Quantistica 3"", ""Luce 1"", ""Livello di Sviluppo Tecnologico 6""",Sinfonia Cosmica di Terracotta,"""Polvere di Crononite"", ""Radici di Gravità"", ""Foglie di Mandragora"", ""Plasma Vitale"", ""Sale Temporale""","""Amalgamazione Sintetica Molecolare"", ""Incisione Elettromagnetica Plasmica"", ""Sferificazione Filamentare a Molecole Vibrazionali"", ""Impasto Gravitazionale Vorticoso""",Pandora
# L'Eco di Pandora,Alessandra Novastella,"""Psionica 3"", ""Temporale 1"", ""Gravitazionale 1"", ""Antimateria 1"", ""Magnetica 1"", ""Quantistica 3"", ""Luce 1"", ""Livello di Sviluppo Tecnologico 6""",Viaggio Cosmico nel Multiverso,"""Shard di Prisma Stellare"", ""Foglie di Nebulosa"", ""Foglie di Mandragora"", ""Carne di Mucca"", ""Essenza di Speziaria""","""Affumicatura Polarizzata a Freddo Iperbarico"", ""Affumicatura Psionica Sensoriale"", ""Saltare in Padella Classica"", ""Sferificazione Filamentare a Molecole Vibrazionali""",Pandora
# L'Eco di Pandora,Alessandra Novastella,"""Psionica 3"", ""Temporale 1"", ""Gravitazionale 1"", ""Antimateria 1"", ""Magnetica 1"", ""Quantistica 3"", ""Luce 1"", ""Livello di Sviluppo Tecnologico 6""",Dimensioni del Mare Stellato,"""Liane di Plasmodio"", ""Carne di Kraken"", ""Carne di Xenodonte"", ""Nettare di Sirena"", ""Essenza di Vuoto""","""Affumicatura Psionica Sensoriale"", ""Fermentazione Quantico Biometrica""",Pandora
# L'Eco di Pandora,Alessandra Novastella,"""Psionica 3"", ""Temporale 1"", ""Gravitazionale 1"", ""Antimateria 1"", ""Magnetica 1"", ""Quantistica 3"", ""Luce 1"", ""Livello di Sviluppo Tecnologico 6""",Danza Luminosa del Multiverso,"""Uova di Fenice"", ""Biscotti della Galassia"", ""Farina di Nettuno"", ""Nettare di Sirena"", ""Essenza di Vuoto""","""Bollitura Entropica Sincronizzata"", ""Saltare in Padella Classica"", ""Cottura Idrodinamica Autoregolante""",Pandora
# L'Eco di Pandora,Alessandra Novastella,"""Psionica 3"", ""Temporale 1"", ""Gravitazionale 1"", ""Antimateria 1"", ""Magnetica 1"", ""Quantistica 3"", ""Luce 1"", ""Livello di Sviluppo Tecnologico 6""",Microcosmo in un Boccone,"""Cristalli di Memoria"", ""Baccacedro"", ""Carne di Mucca"", ""Carne di Xenodonte"", ""Carne di Drago"", ""Biscotti della Galassia"", ""Pane di Luce"", ""Granuli di Nebbia Arcobaleno"", ""Funghi Orbitali"", ""Essenza di Speziaria""","""Impasto a Campi Magnetici Dualistici"", ""Decostruzione Magnetica Risonante"", ""Cryo-Tessitura Energetica Polarizzata""",Pandora
# L'Eco di Pandora,Alessandra Novastella,"""Psionica 3"", ""Temporale 1"", ""Gravitazionale 1"", ""Antimateria 1"", ""Magnetica 1"", ""Quantistica 3"", ""Luce 1"", ""Livello di Sviluppo Tecnologico 6""",Nebulose della Fenice su Vento Lunare,"""Polvere di Stelle"", ""Baccacedro"", ""Foglie di Nebulosa"", ""Uova di Fenice"", ""Fusilli del Vento"", ""Muffa Lunare"", ""Sale Temporale""","""Fermentazione Quantico Biometrica"", ""Congelazione Iperdimensionalmente Stratificata"", ""Incisione Elettromagnetica Plasmica"", ""Saltare in Padella Realtà Energetiche Parallele""",Pandora
# L'Eco di Pandora,Alessandra Novastella,"""Psionica 3"", ""Temporale 1"", ""Gravitazionale 1"", ""Antimateria 1"", ""Magnetica 1"", ""Quantistica 3"", ""Luce 1"", ""Livello di Sviluppo Tecnologico 6""",Nebulose Pensanti: Sinfonia del Multiverso,"""Vero Ghiaccio"", ""Foglie di Nebulosa"", ""Radici di Gravità"", ""Carne di Kraken"", ""Gnocchi del Crepuscolo"", ""Fusilli del Vento"", ""Farina di Nettuno"", ""Funghi Orbitali"", ""Sale Temporale""","""Fermentazione Psionica Energetica"", ""Affumicatura a Stratificazione Quantica""",Pandora
# ```
#
# Questa rappresentazione in CSV include tutti i dettagli richiesti, rispettando le regole di formattazione specificate.
# ----------------------------------------------------------------------------------------------------
# Ecco il file CSV che rappresenta il menù di "L'Eredità Galattica" convertito nel formato richiesto:
#
# ```csv
# Nome ristorante,Nome chef,Licenze ottenute con punteggio,Nome piatto,Ingredienti del piatto,Tecniche per cucinare il piatto,Pianeta
# L'Eredità Galattica,Alessandro Chronos,"""Temporale 3"", ""Gravitazionale 3"", ""Antimateria 1"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 3""",Sinfonia Tempolare Galattica,"""Polvere di Crononite"", ""Radici di Gravità"", ""Liane di Plasmodio"", ""Foglie di Nebulosa"", ""Carne di Kraken"", ""Carne di Mucca"", ""Spaghi del Sole"", ""Pane di Luce"", ""Amido di Stellarion"", ""Funghi Orbitali"", ""Erba Pipa""","""Bollitura Infrasonica Armonizzata"", ""Fermentazione Temporale Sincronizzata"", ""Cottura con Microonde Entropiche Sincronizzate""",Cybertron
# L'Eredità Galattica,Alessandro Chronos,"""Temporale 3"", ""Gravitazionale 3"", ""Antimateria 1"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 3""",Cosmopolis delle Galassie Perdute,"""Polvere di Stelle"", ""Colonia di Mycoflora"", ""Carne di Balena spaziale"", ""Carne di Drago"", ""Teste di Idra"", ""Farina di Nettuno"", ""Lacrime di Unicorno"", ""Spezie Melange""","""Cottura con Microonde Entropiche Sincronizzate"", ""Cottura a Vapore Ecodinamico Bilanciato"", ""Cryo-Tessitura Energetica Polarizzata""",Cybertron
# L'Eredità Galattica,Alessandro Chronos,"""Temporale 3"", ""Gravitazionale 3"", ""Antimateria 1"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 3""",Galassia Risvegliata,"""Frammenti di Supernova"", ""Colonia di Mycoflora"", ""Uova di Fenice"", ""Fibra di Sintetex"", ""Riso di Cassandra"", ""Nettare di Sirena""","""Taglio a Risonanza Sonica Rigenerativa"", ""Decostruzione Ancestrale"", ""Cottura a Forno Dinamico Inversionale""",Cybertron
# L'Eredità Galattica,Alessandro Chronos,"""Temporale 3"", ""Gravitazionale 3"", ""Antimateria 1"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 3""",Sinfonia Temporale nello Spaghi del Sole,"""Polvere di Crononite"", ""Alghe Bioluminescenti"", ""Carne di Xenodonte"", ""Teste di Idra"", ""Spaghi del Sole"", ""Spezie Melange""","""Cottura a Vapore Termocinetica Multipla"", ""Idro-Cristallizzazione Sonora Quantistica"", ""Decostruzione Atomica a Strati Energetici"", ""Affettamento a Pulsazioni Quantistiche"", ""Marinatura tramite Reazioni d'Antimateria Diluite""",Cybertron
# L'Eredità Galattica,Alessandro Chronos,"""Temporale 3"", ""Gravitazionale 3"", ""Antimateria 1"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 3""",Sinfonia di Crepuscolo Celestiale,"""Cristalli di Nebulite"", ""Gnocchi del Crepuscolo"", ""Amido di Stellarion"", ""Farina di Nettuno"", ""Lacrime di Unicorno"", ""Salsa Szechuan""","""Cottura Sottovuoto Antimateria"", ""Fermentazione Quantico Biometrica"", ""Marinatura Temporale Sincronizzata""",Cybertron
# L'Eredità Galattica,Alessandro Chronos,"""Temporale 3"", ""Gravitazionale 3"", ""Antimateria 1"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 3""",Sinfonia di Stagioni Stellari,"""Cristalli di Memoria"", ""Alghe Bioluminescenti"", ""Foglie di Nebulosa"", ""Carne di Drago"", ""Carne di Xenodonte"", ""Fibra di Sintetex"", ""Amido di Stellarion"", ""Funghi Orbitali"", ""Sale Temporale""","""Taglio a Risonanza Sonica Rigenerativa"", ""Decostruzione Ancestrale"", ""Bollitura Termografica a Rotazione Veloce"", ""Bollitura Infrasonica Armonizzata"", ""Cottura Idrodinamica Autoregolante""",Cybertron
# L'Eredità Galattica,Alessandro Chronos,"""Temporale 3"", ""Gravitazionale 3"", ""Antimateria 1"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 3""",Viaggio dei Sensi: Bolla Temporale di Aromi Ancestrali,"""Cristalli di Memoria"", ""Carne di Xenodonte"", ""Carne di Kraken"", ""Teste di Idra"", ""Essenza di Tachioni""","""Cottura a Vapore Termocinetica Multipla"", ""Affumicatura a Stratificazione Quantica"", ""Amalgamazione Sintetica Molecolare""",Cybertron
# L'Eredità Galattica,Alessandro Chronos,"""Temporale 3"", ""Gravitazionale 3"", ""Antimateria 1"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 3""",Sfogliare Galattico di Sogni Temporali,"""Shard di Prisma Stellare"", ""Alghe Bioluminescenti"", ""Lattuga Namecciana"", ""Carne di Xenodonte"", ""Fusilli del Vento"", ""Essenza di Vuoto""","""Cottura al Forno con Paradosso Temporale Cronospeculare"", ""Marinatura a Infusione Gravitazionale"", ""Grigliatura Eletro-Molecolare a Spaziatura Variabile"", ""Taglio a Risonanza Sonica Rigenerativa"", ""Impasto Gravitazionale Vorticoso""",Cybertron
# L'Eredità Galattica,Alessandro Chronos,"""Temporale 3"", ""Gravitazionale 3"", ""Antimateria 1"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 3""",Nebulosa di Fenice con Sinfonia Eterea,"""Cristalli di Nebulite"", ""Fibra di Sintetex"", ""Uova di Fenice"", ""Funghi dell’Etere"", ""Petali di Eco""","""Bollitura Termografica a Rotazione Veloce"", ""Marinatura tramite Reazioni d'Antimateria Diluite"", ""Sinergia Elettro-Osmotica Programmabile""",Cybertron
# L'Eredità Galattica,Alessandro Chronos,"""Temporale 3"", ""Gravitazionale 3"", ""Antimateria 1"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 3""",Sinfonia Temporale al Tocco di Crono,"""Vero Ghiaccio"", ""Lattuga Namecciana"", ""Baccacedro"", ""Carne di Mucca"", ""Uova di Fenice"", ""Pane degli Abissi"", ""Riso di Cassandra"", ""Spaghi del Sole"", ""Spore Quantiche"", ""Essenza di Tachioni""","""Sinergia Elettro-Osmotica Programmabile"", ""Cottura a Vapore Ecodinamico Bilanciato""",Cybertron
# ```
#
# Assicurati di copiare il contenuto in un file con estensione `.csv` per mantenerne la formattazione corretta.
# ----------------------------------------------------------------------------------------------------
# Per convertire il menù del ristorante "L'Essenza dell'Infinito" in formato CSV con le specifiche fornite, bisogna compilare le righe con le informazioni di ciascun piatto. Di seguito è riportato un esempio di come apparirebbe il file CSV:
#
# ```csv
# Nome ristorante,Nome chef,Licenze ottenute con punteggio,Nome piatto,Ingredienti del piatto,Tecniche per cucinare il piatto,Pianeta
# "L'Essenza dell'Infinito",Luna Celestini,"Psionica 4, Temporale 3, Quantistica 8, Luce 2, Livello di Sviluppo Tecnologico 5","Rinascita Cosmica","Frammenti di Supernova, Alghe Bioluminescenti, Radici di Singolarità, Teste di Idra, Uova di Fenice, Amido di Stellarion, Nettare di Sirena, Frutti del Diavolo","Taglio Sinaptico Biomimetico, Cottura a Vapore Termocinetica Multipla",Ego
# "L'Essenza dell'Infinito",Luna Celestini,"Psionica 4, Temporale 3, Quantistica 8, Luce 2, Livello di Sviluppo Tecnologico 5","Il Rapsodo Celestiale","Shard di Materia Oscura, Colonia di Mycoflora, Uova di Fenice, Pane di Luce, Gnocchi del Crepuscolo, Biscotti della Galassia, Funghi Orbitali, Essenza di Vuoto, Sashimi di Magicarp","Saltare in Padella Realtà Energetiche Parallele, Cottura a Vapore Risonante Simbiotico, Affumicatura Temporale Risonante, Affumicatura a Stratificazione Quantica",Ego
# "L'Essenza dell'Infinito",Luna Celestini,"Psionica 4, Temporale 3, Quantistica 8, Luce 2, Livello di Sviluppo Tecnologico 5","Bistecca Cacofonica dell'Infinito","Frammenti di Supernova, Alghe Bioluminescenti, Carne di Kraken, Pane degli Abissi, Farina di Nettuno, Spaghi del Sole, Sale Temporale, Pickle Rick Croccante","Affumicatura Psionica Sensoriale, Affumicatura a Stratificazione Quantica, Cottura a Vapore Termocinetica Multipla, Cottura a Vapore Risonante Simbiotico",Ego
# "L'Essenza dell'Infinito",Luna Celestini,"Psionica 4, Temporale 3, Quantistica 8, Luce 2, Livello di Sviluppo Tecnologico 5","Galassia di Sapori: Il Viaggio Senza Tempo","Shard di Materia Oscura, Foglie di Mandragora, Foglie di Nebulosa, Fibra di Sintetex, Spaghi del Sole, Pane di Luce, Fusilli del Vento, Muffa Lunare, Chocobo Wings","Affumicatura Psionica Sensoriale, Modellatura Onirica Tetrazionale, Fermentazione Quantico Biometrica",Ego
# "L'Essenza dell'Infinito",Luna Celestini,"Psionica 4, Temporale 3, Quantistica 8, Luce 2, Livello di Sviluppo Tecnologico 5","Pizza Cosmica all'Essenza di Drago con Nebbia Arcobaleno e Funghi Orbitali","Cristalli di Nebulite, Teste di Idra, Carne di Drago, Carne di Balena spaziale, Granuli di Nebbia Arcobaleno, Biscotti della Galassia, Amido di Stellarion, Funghi Orbitali, Essenza di Tachioni, Latte+","Affumicatura a Stratificazione Quantica, Affumicatura Psionica Sensoriale",Ego
# "L'Essenza dell'Infinito",Luna Celestini,"Psionica 4, Temporale 3, Quantistica 8, Luce 2, Livello di Sviluppo Tecnologico 5","Mycoflora con Polvere di Stelle Sbagliato","Polvere di Stelle, Colonia di Mycoflora, Teste di Idra, Lacrime di Andromeda, Essenza di Speziaria","Decostruzione Ancestrale, Amalgamazione Sintetica Molecolare, Fermentazione Quantico Biometrica, Bollitura Termografica a Rotazione Veloce",Ego
# "L'Essenza dell'Infinito",Luna Celestini,"Psionica 4, Temporale 3, Quantistica 8, Luce 2, Livello di Sviluppo Tecnologico 5","Nebulosa di Sapori dell'Infinito","Lattuga Namecciana, Foglie di Nebulosa, Carne di Xenodonte, Plasma Vitale, Nduja Fritta Tanto","Congelamento Bio-Luminiscente Sincronico, Saltare in Padella Realtà Energetiche Parallele, Saltare in Padella Classica, Fermentazione Quantico Biometrica",Ego
# "L'Essenza dell'Infinito",Luna Celestini,"Psionica 4, Temporale 3, Quantistica 8, Luce 2, Livello di Sviluppo Tecnologico 5","Sinfonia dell'Infinito: Un Viaggio Gnodale tra Terra e Universi","Radici di Gravità, Uova di Fenice, Carne di Mucca, Carne di Kraken, Lacrime di Andromeda, Essenza di Speziaria","Affumicatura Psionica Sensoriale, Affumicatura Temporale Risonante",Ego
# "L'Essenza dell'Infinito",Luna Celestini,"Psionica 4, Temporale 3, Quantistica 8, Luce 2, Livello di Sviluppo Tecnologico 5","Tris di Verdure con Xenodonte","Cristalli di Memoria, Radici di Gravità, Foglie di Mandragora, Foglie di Nebulosa, Carne di Xenodonte, Fibra di Sintetex, Pane degli Abissi, Essenza di Tachioni","Modellatura Onirica Tetrazionale, Idro-Cristallizzazione Sonora Quantistica, Fermentazione Quantico Biometrica",Ego
# "L'Essenza dell'Infinito",Luna Celestini,"Psionica 4, Temporale 3, Quantistica 8, Luce 2, Livello di Sviluppo Tecnologico 5","Falso Risotto dell'Infinito Multiverso","Cristalli di Memoria, Uova di Fenice, Carne di Balena spaziale, Granuli di Nebbia Arcobaleno, Farina di Nettuno, Funghi Orbitali, Spezie Melange","Congelamento Bio-Luminiscente Sincronico, Fermentazione Psionica Energetica, Saltare in Padella Realtà Energetiche Parallele, Cottura a Vapore Termocinetica Multipla, Taglio Sinaptico Biomimetico",Ego
# ```
#
# Assicurati di mantenere la formattazione delle virgole e delle virgolette doppie per garantire che le liste di ingredienti, tecniche e licenze siano interpretate correttamente in un file CSV.
# ----------------------------------------------------------------------------------------------------
# Ecco la conversione del menù in formato CSV secondo le specifiche fornite:
#
# ```csv
# Nome ristorante,Nome chef,Licenze ottenute con punteggio,Nome piatto,Ingredienti del piatto,Tecniche per cucinare il piatto,Pianeta
# Il Firmamento,Maestro Alessio "Eterno" Stellaris,"""Psionica 4"", ""Temporale 2"", ""Gravitazionale 1"", ""Antimateria 1"", ""Magnetica 1"", ""Quantistica 2"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 4""",Galassia di Fusilli Sferici alla Risonanza Crononica,"""Fusilli del Vento"", ""Nettare di Sirena"", ""Carne di Kraken"", ""Balena Spaziale"", ""Salsa Szechuan"", ""Farina di Nettuno"", ""Polvere di Crononite"", ""Fibra di Sintetex""","""Bollitura Infrasonica Armonizzata"", ""Impasto a Campi Magnetici Dualistici""",Ego
# Il Firmamento,Maestro Alessio "Eterno" Stellaris,"""Psionica 4"", ""Temporale 2"", ""Gravitazionale 1"", ""Antimateria 1"", ""Magnetica 1"", ""Quantistica 2"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 4""",Galassia Rinascente,"""Lattuga Namecciana"", ""Muffa Lunare"", ""Carne di Drago"", ""Uovo di Fenice"", ""Biscotti della Galassia"", ""Carne delle Teste di Idra""","""Cottura a Vapore Ecodinamico Bilanciato"", ""Bollitura Entropica Sincronizzata""",Ego
# Il Firmamento,Maestro Alessio "Eterno" Stellaris,"""Psionica 4"", ""Temporale 2"", ""Gravitazionale 1"", ""Antimateria 1"", ""Magnetica 1"", ""Quantistica 2"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 4""",Mandragora e Radici,"""Polvere di Stelle"", ""Radici di Gravità"", ""Foglie di Mandragora"", ""Lacrime di Unicorno"", ""Nduja Fritta Tanto""","""Congelamento Bio-Luminiscente Sincronico"", ""Cottura Sottovuoto Bioma Sintetico"", ""Cottura Sottovuoto Pulsar Magnetica""",Ego
# Il Firmamento,Maestro Alessio "Eterno" Stellaris,"""Psionica 4"", ""Temporale 2"", ""Gravitazionale 1"", ""Antimateria 1"", ""Magnetica 1"", ""Quantistica 2"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 4""",Galaxia Rinasciata,"""Uova di Fenice"", ""Lacrime di Unicorno"", ""Spezie Melange"", ""Baccacedro"", ""Biscotti della Galassia""","""Modellatura Onirica Tetrazionale"", ""Surgelamento Antimaterico a Risonanza Inversa"", ""Affumicatura Psionica Sensoriale"", ""Cottura a Vapore con Flusso di Particelle Isoarmoniche"", ""Cottura a Vapore Ecodinamico Bilanciato""",Ego
# Il Firmamento,Maestro Alessio "Eterno" Stellaris,"""Psionica 4"", ""Temporale 2"", ""Gravitazionale 1"", ""Antimateria 1"", ""Magnetica 1"", ""Quantistica 2"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 4""",Cosmic Harmony,"""Foglie di Mandragora"", ""Radici di Gravità"", ""Lacrime di Unicorno"", ""Lattuga Namecciana"", ""Petali di Eco""","""Cryo-Tessitura Energetica Polarizzata"", ""Decostruzione Atomica a Strati Energetici"", ""Affumicatura Psionica Sensoriale""",Ego
# Il Firmamento,Maestro Alessio "Eterno" Stellaris,"""Psionica 4"", ""Temporale 2"", ""Gravitazionale 1"", ""Antimateria 1"", ""Magnetica 1"", ""Quantistica 2"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 4""",Nebulosa di Sapori Quantici,"""Riso di Cassandra"", ""Funghi Orbitali"", ""Essenza di Vuoto"", ""Radici di Singolarità"", ""Cristalli di Nebulite""","""Bollitura Infrasonica Armonizzata"", ""Grigliatura Elettro-Molecolare a Spaziatura Variabile"", ""Decostruzione Magnetica Risonante""",Ego
# Il Firmamento,Maestro Alessio "Eterno" Stellaris,"""Psionica 4"", ""Temporale 2"", ""Gravitazionale 1"", ""Antimateria 1"", ""Magnetica 1"", ""Quantistica 2"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 4""",Galassia in Tavola: Sinfonia dei Sensi,"""Spaghi del Sole"", ""Gnocchi del Crepuscolo"", ""Muffa Lunare"", ""Baccacedro"", ""Spezie Melange""","""Cottura a Vapore con Flusso di Particelle Isoarmoniche"", ""Congelamento Bio-Luminiscente Sincronico"", ""Cottura Sottovuoto Pulsar Magnetica""",Ego
# Il Firmamento,Maestro Alessio "Eterno" Stellaris,"""Psionica 4"", ""Temporale 2"", ""Gravitazionale 1"", ""Antimateria 1"", ""Magnetica 1"", ""Quantistica 2"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 4""",Galassie alla Spirale di Vento con Sfera di Ghiaccio Eterno,"""Fusilli del Vento"", ""Carne di Xenodonte"", ""Teste di Idra"", ""Farina di Nettuno"", ""Gnocchi del Crepuscolo"", ""Radici di Gravità"", ""Lacrime di Andromeda"", ""Nduja Fritta Tanto""","""Marinatura Psionica"", ""Modellati Oniricamente Tetrazionalmente"", ""Polarizzata a Freddo Iperbarico""",Ego
# ```
#
# Note:
# - Le tecniche di cottura e gli ingredienti sono elencati tra virgolette triple per mantenere la formattazione delle liste.
# - I livelli delle licenze sono stati convertiti in numeri arabi.
# ----------------------------------------------------------------------------------------------------
# Ecco la conversione del menù in formato CSV secondo le specifiche date:
#
# ```plaintext
# Nome ristorante,Nome chef,Licenze ottenute con punteggio,Nome piatto,Ingredienti del piatto,Tecniche per cucinare il piatto,Pianeta
# "L'Architetto dell'Universo",Alessandra Tempesti,"""Livello di Sviluppo Tecnologico 5"", ""Temporale 3"", ""Luce 2"", ""Gravitazionale 1""","Galassia Riflessa","""Pane degli Abissi"", ""Foglie di Nebulosa"", ""Carne di Balena spaziale"", ""Colonia di Mycoflora"", ""Uova di Fenice"", ""Lacrime di Unicorno"", ""Petali di Eco""","""Affettamento a Pulsazioni Quantistiche"", ""Congelamento Bio-Luminiscente Sincronico""",Klyntar
# "L'Architetto dell'Universo",Alessandra Tempesti,"""Livello di Sviluppo Tecnologico 5"", ""Temporale 3"", ""Luce 2"", ""Gravitazionale 1""","Enigma Celeste","""Carne di drago"", ""Gnocchi del Crepuscolo"", ""Spore Quantiche"", ""Vero Ghiaccio"", ""Pane di Luce""","""Affumicatura a stratificazione quantica"", ""Cottura Olografica Quantum Fluttuante""",Klyntar
# "L'Architetto dell'Universo",Alessandra Tempesti,"""Livello di Sviluppo Tecnologico 5"", ""Temporale 3"", ""Luce 2"", ""Gravitazionale 1""","Galassia d'Aromi Perduti","""Spaghi del Sole"", ""Pane di Luce"", ""Erba Pipa"", ""Lacrime di Unicorno"", ""Cristalli di Nebulite""","""Bollitura Entropica Sincronizzata"", ""Congelamento Bio-Luminiscente Sincronico"", ""Decostruzione Ancestrale""",Klyntar
# "L'Architetto dell'Universo",Alessandra Tempesti,"""Livello di Sviluppo Tecnologico 5"", ""Temporale 3"", ""Luce 2"", ""Gravitazionale 1""","Galassia a Tavola","""Carne di Xenodonte"", ""Teste di Idra"", ""Funghi Orbitali"", ""Liane di Plasmodio"", ""Foglie di Nebulosa"", ""Essenza di Tachioni""","""Grigliatura Elettro-Molecolare a Spaziatura Variabile"", ""Cottura al Forno con Paradosso Temporale Cronospeculare"", ""Cristallizzazione Temporale Reversiva""",Klyntar
# "L'Architetto dell'Universo",Alessandra Tempesti,"""Livello di Sviluppo Tecnologico 5"", ""Temporale 3"", ""Luce 2"", ""Gravitazionale 1""","Portale Astrale di Sapori","""Carne di Kraken"", ""Carne di Balena spaziale"", ""Nebulite"", ""Pane di Luce"", ""Nettare di Sirena"", ""Nduja Fritta Tanto""","""Amalgamazione Sintetica Molecolare""",Klyntar
# "L'Architetto dell'Universo",Alessandra Tempesti,"""Livello di Sviluppo Tecnologico 5"", ""Temporale 3"", ""Luce 2"", ""Gravitazionale 1""","Cosmic Harmony Risotto","""Riso di Cassandra"", ""Polvere di Pulsar"", ""Pane di Luce"", ""Lacrime di Unicorno"", ""Spezie Melange""","""Cottura Sottovuoto Frugale Energeticamente Negativa"", ""Bollitura Termografica a Rotazione Veloce"", ""Cottura a Vapore Termocinetica Multipla""",Klyntar
# "L'Architetto dell'Universo",Alessandra Tempesti,"""Livello di Sviluppo Tecnologico 5"", ""Temporale 3"", ""Luce 2"", ""Gravitazionale 1""","Galassia di Celestial Delight","""soufflé al Vero Ghiaccio"", ""crema di Uova di Fenice"", ""Radici di Singolarità"", ""Colonia di Mycoflora"", ""riduzione di Essenza di Tachioni"", ""pane di Farina di Nettuno""","""Impasto Gravitazionale Vorticoso"", ""Cottura a Vapore Termocinetica Multipla""",Klyntar
# "L'Architetto dell'Universo",Alessandra Tempesti,"""Livello di Sviluppo Tecnologico 5"", ""Temporale 3"", ""Luce 2"", ""Gravitazionale 1""","Pioggia Calante dell'Universo","""Carne di balena spaziale"", ""Spaghi del Sole"", ""shard di materia oscura"", ""plasma vitale"", ""foglie di mandragora"", ""petali di eco"", ""buccia del baccacedro""","""Taglio a risonanza sonica rigenerativa"", ""Bollitura infrasonica armonizzata""",Klyntar
# ...
# ```
#
# Questa rappresentazione in formato CSV segue le specifiche fornite e include tutte le informazioni pertinenti per ogni piatto descritto nel menù.
# ----------------------------------------------------------------------------------------------------
# Per convertire il menù in un file CSV secondo le linee guida fornite, seguiamo la struttura richiesta e inseriamo i dettagli di ogni piatto. Ecco come apparirebbe il file CSV:
#
# ```csv
# Nome ristorante,Nome chef,Licenze ottenute con punteggio,Nome piatto,Ingredienti del piatto,Tecniche per cucinare il piatto,Pianeta
# "Stelle dell'Infinito Celestiale","Jessica Cosmica","""Psionica 1"", ""Temporale 1"", ""Gravitazionale 3"", ""Antimateria 1"", ""Magnetica 1"", ""Quantistica 9"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 6""","La Mucca Che Stordisce l'Universo","""Polvere di Stelle"", ""Lattuga Namecciana"", ""Colonia di Mycoflora"", ""Carne di Mucca"", ""Gnocchi del Crepuscolo"", ""Lacrime di Andromeda"", ""Petali di Eco""","""Cottura Olografica Quantum Fluttuante"", ""Decostruzione Interdimensionale Lovecraftiana""","Namecc"
# "Stelle dell'Infinito Celestiale","Jessica Cosmica","""Psionica 1"", ""Temporale 1"", ""Gravitazionale 3"", ""Antimateria 1"", ""Magnetica 1"", ""Quantistica 9"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 6""","Piccola Odissea Cosmica","""Polvere di Pulsar"", ""Carne di Balena spaziale"", ""Uova di Fenice"", ""Teste di Idra"", ""Spaghi del Sole"", ""Essenza di Vuoto""","""Affettamento a Pulsazioni Quantistiche"", ""Bollitura Entropica Sincronizzata""","Namecc"
# "Stelle dell'Infinito Celestiale","Jessica Cosmica","""Psionica 1"", ""Temporale 1"", ""Gravitazionale 3"", ""Antimateria 1"", ""Magnetica 1"", ""Quantistica 9"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 6""","L'Unicorno piange il Kraken","""Foglie di Nebulosa"", ""Lattuga Namecciana"", ""Carne di Xenodonte"", ""Fibra di Sintetex"", ""Carne di Kraken"", ""Granuli di Nebbia Arcobaleno"", ""Lacrime di Unicorno"", ""Spezie Melange""","""Cottura Olografica Quantum Fluttuante"", ""Saltare in Padella Singolarità Inversa"", ""Cottura con Microonde Entropiche Sincronizzate"", ""Affettamento a Pulsazioni Quantistiche""","Namecc"
# "Stelle dell'Infinito Celestiale","Jessica Cosmica","""Psionica 1"", ""Temporale 1"", ""Gravitazionale 3"", ""Antimateria 1"", ""Magnetica 1"", ""Quantistica 9"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 6""","L'Eternità al Crepuscolo","""Vero Ghiaccio"", ""Foglie di Nebulosa"", ""Carne di Kraken"", ""Fibra di Sintetex"", ""Gnocchi del Crepuscolo"", ""Biscotti della Galassia"", ""Funghi dell’Etere""","""Cottura Sottovuoto Pulsar Magnetica"", ""Affumicatura a Stratificazione Quantica"", ""Marinatura tramite Reazioni d'Antimateria Diluite"", ""Impasto Gravitazionale Vorticoso"", ""Ebollizione Magneto-Cinetica Pulsante""","Namecc"
# "Stelle dell'Infinito Celestiale","Jessica Cosmica","""Psionica 1"", ""Temporale 1"", ""Gravitazionale 3"", ""Antimateria 1"", ""Magnetica 1"", ""Quantistica 9"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 6""","La Balena Sputafuoco","""Frammenti di Supernova"", ""Carne di Balena spaziale"", ""Pane degli Abissi"", ""Funghi dell’Etere"", ""Nduja Fritta Tanto""","""Cottura Sottovuoto Antimateria"", ""Impasto Gravitazionale Vorticoso"", ""Decostruzione Interdimensionale Lovecraftiana"", ""Cottura Sottovuoto Multirealità Collassante"", ""Sferificazione con Campi Magnetici Entropici""","Namecc"
# "Stelle dell'Infinito Celestiale","Jessica Cosmica","""Psionica 1"", ""Temporale 1"", ""Gravitazionale 3"", ""Antimateria 1"", ""Magnetica 1"", ""Quantistica 9"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 6""","Sassi e Sassolini","""Foglie di Mandragora"", ""Radici di Singolarità"", ""Biscotti della Galassia"", ""Farina di Nettuno"", ""Funghi dell’Etere"", ""Spezie Melange""","""Cottura Idrodinamica Autoregolante"", ""Sferificazione con Campi Magnetici Entropici"", ""Impasto Gravitazionale Vorticoso"", ""Affumicatura a Stratificazione Quantica"", ""Grigliatura Plasma Sintetico Risonante""","Namecc"
# "Stelle dell'Infinito Celestiale","Jessica Cosmica","""Psionica 1"", ""Temporale 1"", ""Gravitazionale 3"", ""Antimateria 1"", ""Magnetica 1"", ""Quantistica 9"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 6""","Galassia Ardente","""Frammenti di Supernova"", ""Radici di Singolarità"", ""Foglie di Mandragora"", ""Carne di Kraken"", ""Spaghi del Sole"", ""Amido di Stellarion"", ""Pane di Luce"", ""Muffa Lunare"", ""Spezie Melange""","""Congelamento Bio-Luminiscente Sincronico"", ""Decostruzione Magnetica Risonante"", ""Affettamento a Pulsazioni Quantistiche"", ""Grigliatura Plasma Sintetico Risonante"", ""Decostruzione Interdimensionale Lovecraftiana""","Namecc"
# "Stelle dell'Infinito Celestiale","Jessica Cosmica","""Psionica 1"", ""Temporale 1"", ""Gravitazionale 3"", ""Antimateria 1"", ""Magnetica 1"", ""Quantistica 9"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 6""","Galassia di Cosmo-Delizie","""Vero Ghiaccio"", ""Lattuga Namecciana"", ""Carne di Drago"", ""Amido di Stellarion"", ""Lacrime di Unicorno"", ""Essenza di Speziaria""","""Decostruzione Magnetica Risonante"", ""Cottura Sottovuoto Pulsar Magnetica""","Namecc"
# "Stelle dell'Infinito Celestiale","Jessica Cosmica","""Psionica 1"", ""Temporale 1"", ""Gravitazionale 3"", ""Antimateria 1"", ""Magnetica 1"", ""Quantistica 9"", ""Luce 2"", ""Livello di Sviluppo Tecnologico 6""","Nebulosa di Confini Sfondati","""Shard di Materia Oscura"", ""Radici di Singolarità"", ""Alghe Bioluminescenti"", ""Foglie di Mandragora"", ""Amido di Stellarion"", ""Farina di Nettuno"", ""Plasma Vitale"", ""Petali di Eco""","""Cottura Olografica Quantum Fluttuante"", ""Congelamento Bio-Luminiscente Sincronico"", ""Saltare in Padella Singolarità Inversa"", ""Affumicatura a Stratificazione Quantica"", ""Surgelamento Antimaterico a Risonanza Inversa""","Namecc"
# ```
#
# Questa tabella CSV include tutte le informazioni richieste, mantenendo la formattazione delle liste e convertendo i livelli delle licenze in numeri arabi.
# ----------------------------------------------------------------------------------------------------
# Per convertire il menù fornito in un file CSV, seguendo le specifiche fornite, si deve compilare ogni riga con i dettagli di ciascun piatto e le relative informazioni. Di seguito, il file CSV risultante:
#
# ```csv
# Nome ristorante,Nome chef,Licenze ottenute con punteggio,Nome piatto,Ingredienti del piatto,Tecniche per cucinare il piatto,Pianeta
# "Tutti a TARSvola",Isabella Quantum-Stellari,"Psionica 4, Quantistica 8, Luce 2, Gravitazionale 1, Antimateria 1","Galassia Sensoriale","Frammenti di Supernova, Pane di Luce, Spaghi del Sole, Riso di Cassandra, Nettare di Sirena, Petali di Eco","Marinatura Psionica, Cottura a Vapore Termocinetica Multipla","Tatooine"
# "Tutti a TARSvola",Isabella Quantum-Stellari,"Psionica 4, Quantistica 8, Luce 2, Gravitazionale 1, Antimateria 1","Cosmopastico di Meraviglie Celesti","Carne di Kraken, Uova di Fenice, Carne di Drago, Pane di Luce, Spaghi del Sole, Riso di Cassandra, Spezie Melange","Impasto Gravitazionale Vorticoso, Sinergia Elettro-Osmotica Programmabile, Bollitura Infrasonica Armonizzata, Grigliatura Eletro-Molecolare a Spaziatura Variabile, Marinatura Psionica","Tatooine"
# "Tutti a TARSvola",Isabella Quantum-Stellari,"Psionica 4, Quantistica 8, Luce 2, Gravitazionale 1, Antimateria 1","Sinfonia Cosmica all'Alba di Fenice","Cristalli di Nebulite, Uova di Fenice, Carne di Mucca, Carne di Kraken, Funghi dell’Etere, Essenza di Tachioni","Impasto Gravitazionale Vorticoso, Cottura con Microonde Entropiche Sincronizzate, Cottura a Vapore Ecodinamico Bilanciato, Taglio a Risonanza Sonica Rigenerativa, Grigliatura Eletro-Molecolare a Spaziatura Variabile","Tatooine"
# "Tutti a TARSvola",Isabella Quantum-Stellari,"Psionica 4, Quantistica 8, Luce 2, Gravitazionale 1, Antimateria 1","Sinfonia Cosmica alla Szechuan","Lattuga Namecciana, Colonia di Mycoflora, Teste di Idra, Granuli di Nebbia Arcobaleno, Plasma Vitale, Salsa Szechuan","Saltare in Padella Classica, Cottura a Vapore con Flusso di Particelle Isoarmoniche, Cottura a Vapore Ecodinamico Bilanciato, Impasto Gravitazionale Vorticoso, Cottura con Microonde Entropiche Sincronizzate","Tatooine"
# "Tutti a TARSvola",Isabella Quantum-Stellari,"Psionica 4, Quantistica 8, Luce 2, Gravitazionale 1, Antimateria 1","Sinfonia Cosmica: Il Crescendo delle Stelle","Radici di Gravità, Radici di Singolarità, Liane di Plasmodio, Carne di Balena spaziale, Uova di Fenice, Carne di Kraken, Gnocchi del Crepuscolo, Pane di Luce, Funghi Orbitali, Petali di Eco","Cottura a Forno Dinamico Inversionale, Cottura a Vapore Termocinetica Multipla, Amalgamazione Sintetica Molecolare","Tatooine"
# "Tutti a TARSvola",Isabella Quantum-Stellari,"Psionica 4, Quantistica 8, Luce 2, Gravitazionale 1, Antimateria 1","Cosmofantasia di Terra e Mare nel Vortice delle Stelle","Shard di Materia Oscura, Lattuga Namecciana, Radici di Gravità, Carne di Kraken, Carne di Mucca, Carne di Balena spaziale, Amido di Stellarion, Nettare di Sirena, Essenza di Tachioni","Impasto Gravitazionale Vorticoso, Marinatura Psionica, Cottura a Vapore Termocinetica Multipla","Tatooine"
# "Tutti a TARSvola",Isabella Quantum-Stellari,"Psionica 4, Quantistica 8, Luce 2, Gravitazionale 1, Antimateria 1","Cosmic Symphony di Ghiaccio e Fuoco","Vero Ghiaccio, Colonia di Mycoflora, Radici di Gravità, Pane di Luce, Lacrime di Andromeda, Nduja Fritta Tanto","Cryo-Tessitura Energetica Polarizzata, Grigliatura Eletro-Molecolare a Spaziatura Variabile, Amalgamazione Sintetica Molecolare, Marinatura Psionica","Tatooine"
# "Tutti a TARSvola",Isabella Quantum-Stellari,"Psionica 4, Quantistica 8, Luce 2, Gravitazionale 1, Antimateria 1","Odissea Celestiale","Cristalli di Memoria, Fibra di Sintetex, Carne di Drago, Biscotti della Galassia, Pane degli Abissi, Gnocchi del Crepuscolo, Muffa Lunare, Spezie Melange","Impasto Gravitazionale Vorticoso, Amalgamazione Sintetica Molecolare, Cottura a Vapore con Flusso di Particelle Isoarmoniche","Tatooine"
# "Tutti a TARSvola",Isabella Quantum-Stellari,"Psionica 4, Quantistica 8, Luce 2, Gravitazionale 1, Antimateria 1","Il Banchetto delle Galassie","Lattuga Namecciana, Liane di Plasmodio, Carne di Kraken, Carne di Mucca, Pane di Luce, Pane degli Abissi, Funghi dell’Etere, Essenza di Speziaria","Cottura a Vapore Ecodinamico Bilanciato, Sinergia Elettro-Osmotica Programmabile, Cottura con Microonde Entropiche Sincronizzate, Bollitura Infrasonica Armonizzata","Tatooine"
# "Tutti a TARSvola",Isabella Quantum-Stellari,"Psionica 4, Quantistica 8, Luce 2, Gravitazionale 1, Antimateria 1","Cosmologia Terrestre: Viaggio in Otto Dimensioni","Baccacedro, Radici di Gravità, Foglie di Mandragora, Carne di Mucca, Salsa Szechuan","Cottura a Vapore Ecodinamico Bilanciato, Sinergia Elettro-Osmotica Programmabile","Tatooine"
# ```
#
# Questo CSV contiene le informazioni per ogni piatto del ristorante "Tutti a TARSvola", includendo il nome del ristorante, il nome dello chef, le licenze ottenute e i dettagli di ciascun piatto, come gli ingredienti, le tecniche di cottura e il pianeta di origine. Le licenze sono state convertite in numeri arabi dove necessario.
# ----------------------------------------------------------------------------------------------------
# Ecco la conversione del menu fornito in un file CSV con le colonne specificate e la formattazione richiesta:
#
# ```csv
# Nome ristorante,Nome chef,Licenze ottenute con punteggio,Nome piatto,Ingredienti del piatto,Tecniche per cucinare il piatto,Pianeta
# "Universo Gastronomico di Namecc","Alice Quantum-Rossi","""Psionica 2"", ""Quantistica 15"", ""Temporale 1"", ""Gravitazionale 1"", ""Magnetica 1"", ""Luce 1"", ""Livello di Sviluppo Tecnologico 6""","Risotto dei Multiversi","""Riso di Cassandra"", ""Cristalli di Nebulite"", ""Lacrime di Unicorno"", ""Sale Temporale"", ""Spaghi del Sole""","""Cottura Olografica Quantum Fluttuante"", ""Affumicatura Psionica Sensoriale""","Namecc"
# "Universo Gastronomico di Namecc","Alice Quantum-Rossi","""Psionica 2"", ""Quantistica 15"", ""Temporale 1"", ""Gravitazionale 1"", ""Magnetica 1"", ""Luce 1"", ""Livello di Sviluppo Tecnologico 6""","Panetto di Carne","""Farina di Nettuno"", ""Funghi Orbitali"", ""Pane di Luce"", ""Carne di Kraken"", ""Xenodonte"", ""Pane degli Abissi""","""Affumicatura Temporale Risonante"", ""Sferificazione Filamentare a Molecole Vibrazionali""","Namecc"
# "Universo Gastronomico di Namecc","Alice Quantum-Rossi","""Psionica 2"", ""Quantistica 15"", ""Temporale 1"", ""Gravitazionale 1"", ""Magnetica 1"", ""Luce 1"", ""Livello di Sviluppo Tecnologico 6""","Cosmos Risotto Reale","""Amido di Stellarion"", ""Carne di Kraken"", ""Pane di Luce"", ""Funghi Orbitali""","""Saltare in Padella Realtà Energetiche Parallele"", ""Bollitura Infrasonica Armonizzata""","Namecc"
# "Universo Gastronomico di Namecc","Alice Quantum-Rossi","""Psionica 2"", ""Quantistica 15"", ""Temporale 1"", ""Gravitazionale 1"", ""Magnetica 1"", ""Luce 1"", ""Livello di Sviluppo Tecnologico 6""","La Balena incontra la Mandragora","""Vero Ghiaccio"", ""Radici di Singolarità"", ""Carne di Balena spaziale"", ""Muffa Lunare"", ""Foglie di Mandragora"", ""Pane di Luce"", ""Petali di Eco""","""Taglio a Risonanza Sonica Rigenerativa"", ""Marinatura Temporale Sincronizzata""","Namecc"
# "Universo Gastronomico di Namecc","Alice Quantum-Rossi","""Psionica 2"", ""Quantistica 15"", ""Temporale 1"", ""Gravitazionale 1"", ""Magnetica 1"", ""Luce 1"", ""Livello di Sviluppo Tecnologico 6""","Armonia Cosmica della Fenice","""Polvere di Stelle"", ""Carne di mucca"", ""Uova di Fenice"", ""Fibra di Sintetex"", ""Lacrime di Unicorno""","""Taglio a Risonanza Sonica Rigenerativa"", ""Cottura Sottovuoto Bioma Sintetico""","Namecc"
# "Universo Gastronomico di Namecc","Alice Quantum-Rossi","""Psionica 2"", ""Quantistica 15"", ""Temporale 1"", ""Gravitazionale 1"", ""Magnetica 1"", ""Luce 1"", ""Livello di Sviluppo Tecnologico 6""","Fenice Galattica","""Riso di Cassandra"", ""Cristalli di Nebulite"", ""Alghe Bioluminescenti"", ""Lattuga Namecciana"", ""Uova di Fenice"", ""Muffa Lunare""","""Marinatura Temporale Sincronizzata"", ""Cottura con Microonde Entropiche Sincronizzate""","Namecc"
# "Universo Gastronomico di Namecc","Alice Quantum-Rossi","""Psionica 2"", ""Quantistica 15"", ""Temporale 1"", ""Gravitazionale 1"", ""Magnetica 1"", ""Luce 1"", ""Livello di Sviluppo Tecnologico 6""","Rapsodia Quantistica nel Cosmo","""Carne di Balena Spaziale"", ""Carne di Xenodonte"", ""Cristalli di Nebulite"", ""Fibra di Sintetex"", ""Lacrime di Unicorno""","""Taglio a Risonanza Sonica Rigenerativa"", ""Marinatura Sotto Zero a Polarità Inversa""","Namecc"
# "Universo Gastronomico di Namecc","Alice Quantum-Rossi","""Psionica 2"", ""Quantistica 15"", ""Temporale 1"", ""Gravitazionale 1"", ""Magnetica 1"", ""Luce 1"", ""Livello di Sviluppo Tecnologico 6""","Galassia di Sapore Quantum","""Fusilli del Vento"", ""Alghe Bioluminescenti"", ""Risotto dei Multiversi"", ""Polvere di Crononite"", ""Biscotti della Galassia""","""Idro-Cristallizzazione Sonora Quantistica"", ""Cottura a Vapore Ecodinamico Bilanciato""","Namecc"
# "Universo Gastronomico di Namecc","Alice Quantum-Rossi","""Psionica 2"", ""Quantistica 15"", ""Temporale 1"", ""Gravitazionale 1"", ""Magnetica 1"", ""Luce 1"", ""Livello di Sviluppo Tecnologico 6""","Tris di Carne con Pane","""Pane di Luce"", ""Carne di Xenodonte"", ""Carne di Kraken"", ""Fusilli del Vento"", ""Carne di Balena spaziale"", ""Lacrime di Unicorno"", ""Cristalli di Memoria"", ""Pane degli Abissi""","""Impasto a Campi Magnetici Dualistici"", ""Decostruzione Magnetica Risonante"", ""Cottura Olografica Quantum Fluttuante""","Namecc"
# ```
#
# Queste righe CSV rappresentano i piatti del ristorante "Universo Gastronomico di Namecc" con le relative informazioni strutturate come richiesto.
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Lavoro sul File Ufficiale

# %%
menus = pd.read_csv('Menus to Use\official_menus.csv')

# %%
# Rimuovo le ""    
menus['Licenze'] = menus['Licenze ottenute con punteggio'].str.replace('"','')
menus['Ingredienti'] = menus['Ingredienti del piatto'].str.replace('"','')
menus['Tecniche'] = menus['Tecniche per cucinare il piatto'].str.replace('"','')
# Split colonne
menus['Licenze'] = menus['Licenze'].str.split(', ')
menus['Ingredienti'] = menus['Ingredienti'].str.split(', ')
menus['Tecniche'] = menus['Tecniche'].str.split(', ')

menus_split = menus.drop(columns=['Licenze ottenute con punteggio', 
                                  'Ingredienti del piatto', 
                                  'Tecniche per cucinare il piatto'])

# %%
# Uso explode per rendere separati tutti gli elementi
menus_exploded_lic = menus_split.explode('Licenze')
menus_exploded_lic_tec = menus_exploded_lic.explode('Tecniche')
menus_exploded_final = menus_exploded_lic_tec.explode('Ingredienti')

# %%
menus_exploded_final.to_csv('menus_exploded.csv', index=None)

# %%
menus_exploded = pd.read_csv('menus_exploded.csv')

# %%
# Separo la licenza dal livello
menus_exploded[['Nome Licenza', 'Livello Licenza']] = (menus_exploded.Licenze
 .str.replace(r' (\d+[\'\+]?)(?=$)', r', \1', regex=True)
 .str.split(', ', expand=True))

# %%
menus_complete = menus_exploded.drop(columns='Licenze')

# %%
menus_complete['Nome Licenza'].unique()
# Out:
# array(['Psionica', 'Temporale', 'Gravitazionale', 'Antimateria',
#        'Quantistica', 'Luce', 'Livello di Sviluppo Tecnologico',
#        'Magnetica'], dtype=object)

# %%
menus_complete.to_csv('menus_complete.csv', index=None)

# %% [markdown]
# ## Aggiunta Nuovi Dataset

# %% [markdown]
# Correzione errori

# %% [markdown]
# Aggiungo la distanza dai pianeti

# %%
menus_complete = pd.read_csv('menus_complete.csv')
distances = pd.read_csv('Hackapizza Dataset\Misc\Distanze.csv')

# %%
menus_complete.shape
# Out:
# (36909, 8)

# %%
menus_complete_with_dist = (menus_complete
 .merge(distances, how='left', on='Pianeta')
 .replace('Crocevia Dimensionalev', 'Crocevia Dimensionale'))

# %%
menus_complete_with_dist.shape
# Out:
# (36909, 18)

# %% [markdown]
# Aggiungo le informazioni sulle licenze

# %%
menus_complete_with_dist_lic = (menus_complete_with_dist
 .merge(licenze, left_on='Nome Licenza', right_on='Licenza')
 .drop(columns='Licenza')
 .rename(columns={'Descrizione':'Descrizione licenza'}))

# %%
menus_complete_with_dist_lic.shape
# Out:
# (36909, 20)

# %% [markdown]
# Aggiungo le informazioni sulle tecniche

# %%
menus_complete_with_dist_lic['Tecniche'] = menus_complete_with_dist_lic['Tecniche'].str.strip()
menus_complete_with_dist_lic_tec = (menus_complete_with_dist_lic
 .merge(tecniche, left_on='Tecniche', right_on='Nome Tecnica')
 .drop(columns='Tecniche')
 .rename(columns={'Descrizione':'Descrizione tecnica'})
)

# %%
menus_complete_with_dist_lic_tec.shape
# Out:
# (36909, 24)

# %% [markdown]
# Aggiungo il blog

# %%
blog = pd.read_csv('Hackapizza Dataset\Blogpost\\blogs.csv')

# %%
menus_complete_with_dist_lic_tec_blog = (menus_complete_with_dist_lic_tec
 .merge(blog, left_on='Nome ristorante', right_on='Nome Ristorante', how='left')
 .drop(columns='Nome Ristorante'))

# %% [markdown]
# Aggiungo id piatti

# %%
dishes = (pd.read_json('Hackapizza Dataset\Misc\dish_mapping.json')
          .T
          .reset_index()
          .rename(columns={'index':'Nome piatto', 0:'ID Piatto'})
          )

# %%
menus_complete_with_dist_lic_tec_blog['Nome piatto'] = (menus_complete_with_dist_lic_tec_blog['Nome piatto']
                                                        .replace({
                                                            'Mandragora e Radici':'Mandragola e Radici',
                                                            'Galassia a Tavola':'Galassia a Tavola: Sinfonia di Tempeste Cosmiche',
                                                            'Sinfonia Quantica dell’Oceano Interstellare':"Sinfonia Quantica dell'Oceano Interstellare",
                                                            'Sinfonia Temporale di Fenice e Xenodonte su Pane degli Abissi':"Sinfonia Temporale di Fenice e Xenodonte su Pane degli Abissi con Colata di Plasma Vitale e Polvere di Crononite",
                                                            'Sinfonia dei Ricordi Celesti 🌱':'Sinfonia dei Ricordi Celesti',
                                                            'Il Simposio degli Infiniti Ricordi 🌈':'Il Simposio degli Infiniti Ricordi',
                                                            'Sinfonia Celestiale dei Ricordi 🪐':'Sinfonia Celestiale dei Ricordi',
                                                            'Concordanza Cosmica - Sinfonia di Sapori Multidimensionali':'Concordanza Cosmica',
                                                            'Piastrella Celestiale di Gnocchi del Crepuscolo':"Piastrella Celestiale di Gnocchi del Crepuscolo con Nebulosa di Riso di Cassandra, Lacrime di Unicorno e Velo di Materia Oscura"
                                                        }))

finale = (menus_complete_with_dist_lic_tec_blog
        .merge(dishes, on='Nome piatto'))

# %%
final_df = (menus_complete_with_dist_lic_tec_blog
 .merge(dishes, on='Nome piatto'))

# %%
final_df.shape
# Out:
# (36909, 26)

# %% [markdown]
# Salvataggio dataset definitivo da utilizzare

# %%
final_df.to_csv('Menus to Use\dataset_finale_menu_licenze_tecniche.csv', index=None)

# %% [markdown]
# # Avvio Nuovo Flusso

# %%
ristoranti_galassia_df = pd.read_csv('Menus to Use\dataset_finale_menu_licenze_tecniche.csv')
ordini_galattici = pd.read_csv('Hackapizza Dataset\Misc\ordini.csv')
questions = pd.read_csv('Hackapizza Dataset\domande.csv').domanda.values.tolist()

# %%
ristoranti_galassia_df['Nome Sotto Tecnica'].unique()
# Out:
# array(['Vapore', 'Tecniche di Taglio', 'Forno', 'Affumicatura',
#        'Saltare in Padella', 'Marinatura', 'Surgelamento', 'Impasto',
#        'Bollitura', 'Grigliare', 'Sottovuoto', 'Decostruzione',
#        'Sferificazione', 'Fermentazione'], dtype=object)

# %%
final_answers = {}

# %%
# Model
formattatore_llm = ChatOpenAI(temperature=.3, model='gpt-4o')

# Prompt
formattatore_prompt = PromptTemplate(
    template='''
    Ruolo:
    Sei il Formattatore. Il tuo compito è ricevere una domanda dall'utente e fornire istruzioni dettagliate all'Assistente su come effettuare query sul dataset disponibile.

    Dataset a disposizione dell'Assistente:
    Il dataset fornito contiene informazioni sui piatti disponibili, con le seguenti colonne:

    Nome ristorante
    Nome chef
    Nome piatto
    Pianeta
    Nome licenza
    Livello licenza
    distanza_da: queste colonne hanno il format distanza_da_Nomepianeta (ad esempio distanza_da_Ego)
    Sigla licenza: abbreviazione della licenza richiesta
    Descrizione licenza: cosa fa quella licenza
    Nome Tecnica Generale: una delle seguenti ('Cottura', 'Avanzate', 'Preparazione') 
    Nome Sotto Tecnica: una delle seguenti ('Vapore', 'Tecniche di Taglio', 'Forno', 'Affumicatura','Saltare in Padella', 'Marinatura', 'Surgelamento', 'Impasto','Bollitura', 'Grigliare', 'Sottovuoto', 'Decostruzione', 'Sferificazione', 'Fermentazione')
    Nome Tecnica
    Descrizione Tecnica
    ID Piatto

    
    Riassunto sugli Ordini Galattici:
    Alcuni ordini galattici impongono restrizioni alimentari. L’Assistente deve essere in grado di filtrare i piatti in base a queste limitazioni:

    Ordine della Galassia di Andromeda → Vietati ingredienti di origine sintetica e il lattosio (latte, burro, panna, ecc.).
    Ordine dei Naturalisti → Consentiti solo ingredienti vegetali e naturali, nessun derivato animale o artificiale. Nessuna trasformazione drastica, niente manipolazioni invasive.
    Ordine degli Armonisti → Solo piatti che permettono di sintonizzarsi con lo stato emotivo di chi li assapora.
    
    Regole fondamentali:
    Esiste sempre almeno un piatto che soddisfa la richiesta dell'utente.
    La tua risposta deve essere strutturata in step chiari e sequenziali, indicando quali operazioni l'Assistente deve eseguire per filtrare il dataset.
    Se la domanda fa riferimento a tecniche, licenze o ingredienti, devi individuare i criteri di filtraggio adeguati.
    L’output finale dell’Assistente sarà una lista ordinata di ID dei piatti che soddisfano la richiesta.
    Il filtraggio è complesso perché molte colonne sono stringhe; pertanto, le istruzioni devono essere specifiche e dettagliate.
    Esempi di istruzioni:
    Domanda: "Trova i piatti che utilizzano almeno una tecnica di affumicatura e contengono agrumi."
    Istruzioni per l’Assistente:

    Filtra il dataset per individuare i piatti che utilizzano almeno una tecnica di affumicatura.
    Filtra ulteriormente i risultati per selezionare solo i piatti che contengono agrumi tra gli ingredienti.
    Restituisci gli ID dei piatti ordinati in ordine crescente.
    Domanda: "Mostrami i piatti preparati su Andromeda che non richiedono licenze speciali."
    Istruzioni per l’Assistente:

    Filtra il dataset per trovare i piatti il cui pianeta di origine è Andromeda.
    Escludi i piatti che richiedono qualsiasi tipo di licenza speciale.
    Restituisci gli ID dei piatti ordinati in ordine crescente.
    Domanda: "Trova un piatto compatibile con l’Ordine dei Naturalisti che utilizzi almeno una tecnica di fermentazione."
    Istruzioni per l’Assistente:

    Escludi dal dataset i piatti che contengono ingredienti di origine animale o artificiale.
    Filtra il dataset per ottenere l’elenco delle tecniche di fermentazione.
    Seleziona i piatti che utilizzano almeno una di queste tecniche.
    Restituisci gli ID dei piatti ordinati in ordine crescente.
    Devi essere preciso e specifico nel definire i criteri di filtraggio per l’Assistente.

    Ecco un esempio delle prime due righe del dataset:

    Nome ristorante,Nome chef,Nome piatto,Pianeta,Ingredienti,Nome Licenza,Livello Licenza,distanza_da_Tatooine,distanza_da_Asgard,distanza_da_Namecc,distanza_da_Arrakis,distanza_da_Krypton,distanza_da_Pandora,distanza_da_Cybertron,distanza_da_Ego,distanza_da_Montressosr,distanza_da_Klyntar,Sigla Licenza,Descrizione licenza,Nome Tecnica Generale,Nome Sotto Tecnica,Nome Tecnica,Descrizione tecnica,Recensione,ID Piatto
    Anima Cosmica,Aurora Stellaris,Nebulosa Celestiale alla Stellaris,Pandora,"""Shard di Materia Oscura""",Psionica,3,1130.0,473.0,987.0,1227.0,626.0,0.0,847.0,317.0,413.0,731.0,P,"Livello 0: Posseduta da tutti se non diversamente specificato. Tipica degli esseri senzienti.; Livello I: lettura pensiero, telecinesi e teletrasporto di oggetti di massa inferiore a 5 kg, precognizione e visione del passato fino a 5 minuti; Livello II: manipolazione della probabilità, telecinesi e teletrasporto di oggetti di massa inferiore a 20 kg, manipolazione delle forze fondamentali dellʼuniverso; Livello III: capacità di donare la coscienza e lʼintelletto ad oggetti, manipolazione della realtà circoscritta a stanze, teletrasporto senza errore in qualsiasi dimensione temporale, comunione con entità di altri piani; Livello IV: proiezione astrale, riscrittura di realtà circoscritta a piccole nazioni o asteroidi; Livello V: riscrittura di realtà di intere linee temporali o galassie. Questo livello è equivalente al Grado di influenza di livello tecnologico III (LTK III)",Cottura,Vapore,Cottura a Vapore con Flusso di Particelle Isoarmoniche,genera vapore attraverso il controllo di particelle isoarmoniche in sintonia con la struttura molecolare del cibo,,127
    Anima Cosmica,Aurora Stellaris,Nebulosa Celestiale alla Stellaris,Pandora,"""Carne di Balena spaziale""",Psionica,3,1130.0,473.0,987.0,1227.0,626.0,0.0,847.0,317.0,413.0,731.0,P,"Livello 0: Posseduta da tutti se non diversamente specificato. Tipica degli esseri senzienti.; Livello I: lettura pensiero, telecinesi e teletrasporto di oggetti di massa inferiore a 5 kg, precognizione e visione del passato fino a 5 minuti; Livello II: manipolazione della probabilità, telecinesi e teletrasporto di oggetti di massa inferiore a 20 kg, manipolazione delle forze fondamentali dellʼuniverso; Livello III: capacità di donare la coscienza e lʼintelletto ad oggetti, manipolazione della realtà circoscritta a stanze, teletrasporto senza errore in qualsiasi dimensione temporale, comunione con entità di altri piani; Livello IV: proiezione astrale, riscrittura di realtà circoscritta a piccole nazioni o asteroidi; Livello V: riscrittura di realtà di intere linee temporali o galassie. Questo livello è equivalente al Grado di influenza di livello tecnologico III (LTK III)",Cottura,Vapore,Cottura a Vapore con Flusso di Particelle Isoarmoniche,genera vapore attraverso il controllo di particelle isoarmoniche in sintonia con la struttura molecolare del cibo,,127

    Devi suggerire che la ricerca deve avvenire per step.
    Ad esempio, per cercare una determinata tecnica o licenza, prima deve vedere tutte le tecniche disponibili, poi le loro descrizioni ed infine cercare quelle che meglio soddisfano la richiesta.
    Domanda utente: {domanda_originale}
    ''',
    input_variables = ['domanda_originale']
)

# Formattatore chain
formattatore = formattatore_prompt | formattatore_llm | StrOutputParser()

# %%
# Funzione per impedire il NameError in fase di tool invocation

PythonAstREPLTool_init = PythonAstREPLTool.__init__

def PythonAstREPLTool_init_wrapper(self, *args, **kwargs):
    PythonAstREPLTool_init(self, *args, **kwargs)
    self.globals = self.locals

PythonAstREPLTool.__init__ = PythonAstREPLTool_init_wrapper

# %%
# Model
assistente_llm = ChatOpenAI(temperature=.7, model='gpt-4o')

# Assistente

assistente_agent = create_pandas_dataframe_agent(
    assistente_llm,
    ristoranti_galassia_df,
    agent_type='openai-functions',
    extra_tools=[PythonAstREPLTool()],
    verbose=True,
    allow_dangerous_code=True,
    prefix='''
    Sei l’Assistente, il tuo compito è eseguire query su dataset pandas seguendo scrupolosamente le istruzioni fornite dal Formattatore. Alla fine, devi restituire gli ID dei piatti ordinati in ordine crescente.

    Dataset a tua disposizione:
    
    ristoranti_galassia_df:
    Path per accedere a menus: "Menus to Use\dataset_finale_menu_licenze_tecniche.csv"
    
    Come operare:
    
    Leggi attentamente le istruzioni fornite dal Formattatore.
    Identifica i dataset da interrogare e i criteri di filtraggio richiesti.
    Applica le operazioni di filtraggio e selezione per ottenere il risultato corretto.
    Restituisci una lista di ID dei piatti in ordine crescente.
    Esempi di richieste che potresti ricevere:
    
    "Trova i piatti che utilizzano almeno una tecnica di Taglio e una di Surgelamento."
    
    Devi estrarre l'elenco delle tecniche di queste due categorie e filtrare i piatti che ne usano almeno una per ciascuna.
    "Individua i piatti compatibili con l'Ordine della Galassia di Andromeda, che non contengono ingredienti vietati e usano almeno una tecnica di Fermentazione."
    
    Devi escludere i piatti con ingredienti proibiti e selezionare quelli che usano una tecnica di fermentazione.
    "Trova i piatti che richiedono almeno una licenza di livello II o superiore."
    
    Devi individuare le licenze di livello II o superiore e filtrare i piatti che le richiedono.
    
    Regole importanti:
    
    Ricorda che Sirius Cosmo è solo uno chef, lo scrittore del libro di cucina da cui derivano le tecniche nel dataset. Non appare nel dataset.
    Segui esattamente le istruzioni fornite dal Formattatore.
    Usa solo i dataset disponibili e le operazioni indicate.
    Restituisci sempre una lista di ID in ordine crescente.
    Seleziona solo le colonne necessarie per ottimizzare le query.
    Il tuo obiettivo è ottenere il risultato corretto nel modo più efficiente possibile. 
    Devi sempre restituire almeno un id. Esiste sempre almeno un piatto che soddisfa la richiesta. 
    Se non trovi un piatto cerca meglio, magari correggendo possibili errori di battitura oppure ampliando la ricerca.
    Non puoi rispondere che un piatto non esiste. Esiste per forza almeno un piatto.
    Utilizza le colonne di descrizione per leggere info relative alle licenze o alle tecniche, soprattutto per le domande relative agli ordini galattici.

    Gestione degli errori di battitura negli ingredienti
    Gli ingredienti presenti nel dataset menus potrebbero contenere errori di battitura o leggere variazioni nel nome. Se un ingrediente specificato nella richiesta dell'utente non corrisponde esattamente a nessuno di quelli nel dataset, devi:

    Cercare la corrispondenza più simile nel dataset usando una misura di similarità testuale (es. confronto del numero di caratteri uguali o la distanza di Levenshtein).
    Scegliere l'ingrediente con il nome più vicino a quello richiesto, purché la differenza sia minima e non alteri significativamente il significato.
    Se ci sono più alternative valide, preferire quella con la somiglianza più alta.
    Esempio:

    L'utente chiede un piatto senza "Polvere di Crononitte", ma nel dataset trovi solo "Polvere di Crononite". In questo caso, devi trattarli come lo stesso ingrediente ed escludere i piatti che lo contengono.
    Se l'utente cerca un piatto con "Fungo Stellare" ma trovi solo "Funghi Stellari", considerali equivalenti.
    L'obiettivo è evitare di scartare piatti corretti solo a causa di piccoli errori di scrittura.
    
    Non usare altre librerie oltre pandas.

    Utilizza i vari step che hai per ragiornare.
    Se non trovi un'informazione in una colonna prova cercando in un'altra ricordandoti della ricerca precedente.
    Non possono essere presenti tutti i piatti contemporaneamente, ma solo alcuni.
    Se una query ti ritorna tutti i piatti riprova.
    
    Restituisci solo l'id o gli id che trovi, senza aggiungere altro. Ad esempio:
     "1"
     "3, 19"
    
    ''',
    max_iterations=10
    )

# Assistente chain
assistente = {'input':RunnablePassthrough()} | assistente_agent | (lambda x: x['output'])

# %%
# Domanda
question = questions[0]

# Formattatore
risposta_formattatore = formattatore.invoke(
     {
          'domanda_originale':question
     }
)

# Assistente
risposta_assistente = assistente.invoke(risposta_formattatore)

# Scrittura nel dizionario
final_answers['1'] = [risposta_assistente]
#final_answers[list(final_answers.keys())[-1]]
final_answers['1']
